# %%
from copy import deepcopy

import pandas as pd
import json
from pathlib import Path

# %%
data = json.loads(Path(
    "/home/egordm/Projects/workshops/hackalod-gouda23-na-td/data/suppleties/nl_zh_ha_na-2_10_50-505_13_page_data.json").read_text())

# %%
data
# Out:
# {'creator': 'READ-COOP',
#  'model_name': 'TrHtr',
#  'model_version': '2.3.0',
#  'model_identifier': '51170',
#  'model_date': '04_10_2023_12',
#  'created': '2023-10-03T17:32:38.967+02:00',
#  'last_change': '2023-11-04T00:06:39.070+01:00',
#  'measurement_unit': 'pixel',
#  'primary_language': None,
#  'producer': 'Transkribus',
#  'image': {'image_filename': 'nl_zh_ha_na-2_10_50-505_13.jpg',
#   'image_width': 8374,
#   'image_height': 5897,
#   'image_size': 8384,
#   'bbox_page_coordinates': [118, 132, 8123, 5787],
#   'page_area': 43564793.0,
#   'page_contour_shape': 'rectangular'},
#  'regions': {'0': {'region_orientation': '0',
#    'region_type': 'table_row',
#    'identifier': 'region_1696352088230_1364',
#    'reading_order': '0',
#    'structure': 'index',
#    'shape_class': 'Rectangle',
#    'coordinates_list': [['267', '1395'],
#     ['267', '1463'],
#     ['456', '1463'],
#     ['456', '1395']],
#    'bbox_height': 68,
#    'bbox_width': 189,
#    'bbox_area': 12852,
#    'bbox_area_relative': 0.00029500886185778504,
#    'centroid': [361.5, 1429.0],
#    'textlines': {'0': {'line_id': 'line_1696352088269_1367',
#      'annotation': 'readingOrder {index:0;}',
#      'text': '5118',
#      'polygon_coordinates': [[255, 1468],
#       [285, 1463],
#       [295, 1476],
#       [318, 1481],
#       [335, 1503],
#       [356, 1486],
#       [368, 1503],
#       [426, 1463],
#       [446, 1463],
#       [457, 1360],
#       [411, 1344],
#       [394, 1362],
#       [356, 1357],
#       [341, 1365],
#       [335, 1357],
#       [310, 1365],
#       [290, 1385],
#       [265, 1382]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 22351.0,
#      'area_estimated_polygon_relative': 0.0005130519040914529,
#      'centroid_polygon': [360.17957436654586, 1421.182773328561],
#      'line_mean_y': 1449.0,
#      'line_coordinates': [[271, 1458], [456, 1440]],
#      'line_extent': 185,
#      'line_total_characters': 4,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 18,
#      'line_total_base_points': 2,
#      'line_character_density': 46.25,
#      'line_character_per_point': 2.0,
#      'baselines_coordinates': {'0': {'extent': 185}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 92.5,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'}},
#    'region_text': '5118 ',
#    'text_largest': '5118',
#    'row_surname': '5118'},
#   '1': {'region_orientation': '0',
#    'region_type': 'marginalia',
#    'identifier': 'TextRegion_1698738733163_29',
#    'reading_order': '153',
#    'structure': 'page_number',
#    'shape_class': 'Parallelogram',
#    'coordinates_list': [['543', '229'],
#     ['865', '233'],
#     ['927', '411'],
#     ['605', '407']],
#    'bbox_height': 182,
#    'bbox_width': 384,
#    'bbox_area': 69888,
#    'bbox_area_relative': 0.0016042311965076938,
#    'centroid': [735.0, 320.0],
#    'textlines': {'0': {'line_id': 'tr_3_tl_1',
#      'annotation': 'readingOrder {index:0;}',
#      'text': '1707',
#      'polygon_coordinates': [[618, 373],
#       [646, 376],
#       [668, 366],
#       [681, 378],
#       [694, 368],
#       [742, 378],
#       [774, 358],
#       [812, 388],
#       [832, 376],
#       [855, 381],
#       [858, 267],
#       [787, 265],
#       [747, 275],
#       [734, 262],
#       [621, 265]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 25595.5,
#      'area_estimated_polygon_relative': 0.0005875271804918252,
#      'centroid_polygon': [738.4600483157847, 319.7175024255566],
#      'line_mean_y': 361.0,
#      'line_coordinates': [[632, 364], [680, 364], [769, 358], [859, 358]],
#      'line_extent': 227,
#      'line_total_characters': 4,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 4,
#      'line_character_density': 56.75,
#      'line_character_per_point': 1.0,
#      'baselines_coordinates': {'0': {'extent': 48},
#       '1': {'direct_angle': -8.325650330426836, 'extent': 89},
#       '2': {'direct_angle': 80.53767779197439, 'extent': 90},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 48.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'}},
#    'region_text': '1707 ',
#    'text_largest': '1707'},
#   '2': {'region_orientation': '0',
#    'region_type': 'table_row',
#    'identifier': 'tr_5',
#    'reading_order': '159',
#    'structure': 'index',
#    'shape_class': 'Parallelogram',
#    'coordinates_list': [['596', '3880'],
#     ['2422', '3889'],
#     ['2437', '5414'],
#     ['611', '5405']],
#    'bbox_height': 1534,
#    'bbox_width': 1841,
#    'bbox_area': 2824094,
#    'bbox_area_relative': 0.06482514446929658,
#    'centroid': [1516.5, 4647.0],
#    'textlines': {'0': {'line_id': 'tr_5_tl_1',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'J.J. Montagne',
#      'polygon_coordinates': [[1387, 4119],
#       [1705, 4099],
#       [1761, 4124],
#       [1910, 4097],
#       [2005, 4129],
#       [2109, 4069],
#       [2268, 4079],
#       [2268, 4013],
#       [2099, 4018],
#       [2028, 3968],
#       [1799, 3965],
#       [1708, 4021],
#       [1645, 3970],
#       [1287, 3937],
#       [1095, 4018]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 137606.0,
#      'area_estimated_polygon_relative': 0.0031586515285404893,
#      'centroid_polygon': [1663.5449350561264, 4035.2818275850373],
#      'line_mean_y': 4065.909090909091,
#      'line_coordinates': [[1208, 4073],
#       [1402, 4082],
#       [1468, 4076],
#       [1557, 4070],
#       [1647, 4064],
#       [1736, 4058],
#       [1826, 4058],
#       [1915, 4058],
#       [2005, 4058],
#       [2094, 4070],
#       [2184, 4070],
#       [2274, 4070]],
#      'line_extent': 1066,
#      'line_total_characters': 13,
#      'line_total_punctuation': 2,
#      'line_total_spaces': 1,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 12,
#      'line_character_density': 82.0,
#      'line_character_per_point': 1.0833333333333333,
#      'baselines_coordinates': {'0': {'extent': 194},
#       '1': {'direct_angle': -173.3161358919659, 'extent': 66},
#       '2': {'direct_angle': 0.0, 'extent': 89},
#       '3': {'direct_angle': 0.0, 'extent': 90},
#       '4': {'direct_angle': 180.0, 'extent': 89},
#       '5': {'direct_angle': 80.53767779197439, 'extent': 90},
#       '6': {'direct_angle': 180.0, 'extent': 89},
#       '7': {'direct_angle': 0.0, 'extent': 90},
#       '8': {'direct_angle': 94.76364169072617, 'extent': 89},
#       '9': {'direct_angle': -85.23635830927383, 'extent': 90},
#       '10': {'direct_angle': 0.0, 'extent': 90},
#       '11': {}},
#      'regular_base_points': True,
#      'point_char_density': 83.07692307692308,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'tr_5_tl_2',
#      'annotation': 'readingOrder {index:1;}',
#      'text': '5120',
#      'polygon_coordinates': [[621, 4697],
#       [646, 4692],
#       [663, 4674],
#       [679, 4684],
#       [691, 4674],
#       [739, 4677],
#       [767, 4662],
#       [790, 4672],
#       [820, 4667],
#       [810, 4535],
#       [795, 4535],
#       [777, 4558],
#       [769, 4553],
#       [762, 4561],
#       [719, 4551],
#       [701, 4563],
#       [681, 4558],
#       [661, 4573],
#       [648, 4566],
#       [613, 4573]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 23656.5,
#      'area_estimated_polygon_relative': 0.0005430187628803837,
#      'centroid_polygon': [716.6243456696186, 4617.274406611291],
#      'line_mean_y': 4647.0,
#      'line_coordinates': [[632, 4637], [722, 4643], [811, 4649], [823, 4649]],
#      'line_extent': 191,
#      'line_total_characters': 4,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 20,
#      'line_total_base_points': 4,
#      'line_character_density': 47.75,
#      'line_character_per_point': 1.0,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 180.0, 'extent': 89},
#       '2': {'direct_angle': -175.5443971666737, 'extent': 12},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 90.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'},
#     '2': {'line_id': 'tr_5_tl_3',
#      'annotation': 'readingOrder {index:2;}',
#      'text': 'Montagne',
#      'polygon_coordinates': [[1112, 4776],
#       [1971, 4782],
#       [1923, 4930],
#       [2041, 4938],
#       [2122, 4784],
#       [2385, 4768],
#       [2383, 4583],
#       [2139, 4586],
#       [1945, 4457],
#       [1748, 4533],
#       [1644, 4343],
#       [1508, 4345],
#       [1109, 4562]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 398183.5,
#      'area_estimated_polygon_relative': 0.009140029656516445,
#      'centroid_polygon': [1707.676572066229, 4631.9213511693315],
#      'line_mean_y': 4729.5,
#      'line_coordinates': [[1229, 4715],
#       [1319, 4715],
#       [1408, 4727],
#       [1498, 4727],
#       [1587, 4727],
#       [1677, 4733],
#       [1766, 4727],
#       [1856, 4733],
#       [1945, 4733],
#       [2035, 4733],
#       [2124, 4733],
#       [2214, 4727],
#       [2303, 4727],
#       [2345, 4727]],
#      'line_extent': 1116,
#      'line_total_characters': 8,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 13,
#      'line_total_base_points': 14,
#      'line_character_density': 139.5,
#      'line_character_per_point': 0.5714285714285714,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 94.76364169072617, 'extent': 89},
#       '2': {'direct_angle': -85.23635830927383, 'extent': 90},
#       '3': {'direct_angle': 180.0, 'extent': 89},
#       '4': {'direct_angle': 80.53767779197439, 'extent': 90},
#       '5': {'direct_angle': -94.76364169072617, 'extent': 89},
#       '6': {'direct_angle': 85.23635830927383, 'extent': 90},
#       '7': {'direct_angle': -99.46232220802563, 'extent': 89},
#       '8': {'direct_angle': 0.0, 'extent': 90},
#       '9': {'direct_angle': 180.0, 'extent': 89},
#       '10': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '11': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '12': {'direct_angle': 180.0, 'extent': 42},
#       '13': {}},
#      'regular_base_points': True,
#      'point_char_density': 157.5,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '2'},
#     '3': {'line_id': 'tr_5_tl_4',
#      'annotation': 'readingOrder {index:3;}',
#      'text': 'Johannes, Jacobus',
#      'polygon_coordinates': [[1231, 5113],
#       [1372, 5060],
#       [1445, 5080],
#       [1665, 5060],
#       [1720, 5098],
#       [1864, 5068],
#       [1985, 5085],
#       [1978, 4947],
#       [1925, 4929],
#       [1844, 4926],
#       [1572, 5010],
#       [1433, 5007],
#       [1382, 4979],
#       [1274, 5012],
#       [1226, 4990]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 75881.5,
#      'area_estimated_polygon_relative': 0.001741807886014746,
#      'centroid_polygon': [1656.5916308103206, 5023.091697800737],
#      'line_mean_y': 5057.25,
#      'line_coordinates': [[1241, 5037],
#       [1331, 5037],
#       [1420, 5043],
#       [1510, 5049],
#       [1599, 5055],
#       [1689, 5061],
#       [1778, 5061],
#       [1868, 5061],
#       [1957, 5061],
#       [1987, 5067]],
#      'line_extent': 746,
#      'line_total_characters': 17,
#      'line_total_punctuation': 1,
#      'line_total_spaces': 1,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 10,
#      'line_character_density': 43.88235294117647,
#      'line_character_per_point': 1.7,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '2': {'direct_angle': 0.0, 'extent': 90},
#       '3': {'direct_angle': 180.0, 'extent': 89},
#       '4': {'direct_angle': 0.0, 'extent': 90},
#       '5': {'direct_angle': -99.46232220802563, 'extent': 89},
#       '6': {'direct_angle': 0.0, 'extent': 90},
#       '7': {'direct_angle': 180.0, 'extent': 89},
#       '8': {'direct_angle': 174.19327309446842, 'extent': 30},
#       '9': {}},
#      'regular_base_points': True,
#      'point_char_density': 52.94117647058824,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '3'},
#     '4': {'line_id': 'tr_5_tl_5',
#      'annotation': 'readingOrder {index:4;}',
#      'text': 'V. P.',
#      'polygon_coordinates': [[1236, 5401],
#       [1266, 5398],
#       [1286, 5378],
#       [1304, 5386],
#       [1370, 5358],
#       [1433, 5378],
#       [1461, 5375],
#       [1463, 5227],
#       [1433, 5219],
#       [1410, 5234],
#       [1390, 5232],
#       [1360, 5227],
#       [1344, 5211],
#       [1297, 5244],
#       [1239, 5242]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 32801.5,
#      'area_estimated_polygon_relative': 0.0007529359774531696,
#      'centroid_polygon': [1348.9547835718895, 5304.369388595033],
#      'line_mean_y': 5359.0,
#      'line_coordinates': [[1253, 5365],
#       [1289, 5359],
#       [1378, 5359],
#       [1468, 5359]],
#      'line_extent': 215,
#      'line_total_characters': 5,
#      'line_total_punctuation': 2,
#      'line_total_spaces': 1,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 4,
#      'line_character_density': 43.0,
#      'line_character_per_point': 1.25,
#      'baselines_coordinates': {'0': {'extent': 36},
#       '1': {'direct_angle': 6.458816378718656, 'extent': 89},
#       '2': {'direct_angle': 0.0, 'extent': 90},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 28.8,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '4'}},
#    'region_text': 'J.J. Montagne 5120 Montagne Johannes, Jacobus V. P. ',
#    'text_largest': 'Montagne',
#    'row_surname': 'Montagne',
#    'row_name': 'Johannes, Jacobus',
#    'row_index_numbers': ['5120']},
#   '3': {'region_orientation': '0',
#    'region_type': 'table_row',
#    'identifier': 'tr_8',
#    'reading_order': '158',
#    'structure': 'index',
#    'shape_class': 'Quadrilateral',
#    'coordinates_list': [['610', '2339'],
#     ['2410', '2353'],
#     ['2407', '3889'],
#     ['631', '3871']],
#    'bbox_height': 1550,
#    'bbox_width': 1800,
#    'bbox_area': 2790000,
#    'bbox_area_relative': 0.06404254003915501,
#    'centroid': [1514.8993312302564, 3111.286011912575],
#    'textlines': {'0': {'line_id': 'line_1697404135210_10635',
#      'annotation': 'readingOrder {index:0;}',
#      'text': '63635',
#      'polygon_coordinates': [[891, 2990],
#       [1077, 2980],
#       [1079, 3030],
#       [893, 3040]],
#      'shape_class_polygon': 'Parallelogram',
#      'area_estimated_polygon': 9320.0,
#      'area_estimated_polygon_relative': 0.00021393421977237444,
#      'centroid_polygon': [985.0, 3010.0],
#      'line_mean_y': 3030.0,
#      'line_coordinates': [[893, 3035], [1079, 3025]],
#      'line_extent': 186,
#      'line_total_characters': 5,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 4,
#      'line_total_base_points': 2,
#      'line_character_density': 37.2,
#      'line_character_per_point': 2.5,
#      'baselines_coordinates': {'0': {'extent': 186}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 74.4,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'tr_8_tl_2',
#      'annotation': 'readingOrder {index:1;}',
#      'text': '5119',
#      'polygon_coordinates': [[636, 3153],
#       [648, 3153],
#       [656, 3146],
#       [679, 3153],
#       [686, 3148],
#       [701, 3153],
#       [709, 3146],
#       [721, 3151],
#       [732, 3148],
#       [781, 3148],
#       [779, 3123],
#       [784, 3045],
#       [757, 3042],
#       [752, 3047],
#       [747, 3042],
#       [724, 3055],
#       [706, 3042],
#       [676, 3062],
#       [663, 3057],
#       [656, 3062],
#       [641, 3060]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 13999.5,
#      'area_estimated_polygon_relative': 0.00032134893880937296,
#      'centroid_polygon': [711.9551412550449, 3099.9614986249508],
#      'line_mean_y': 3137.0,
#      'line_coordinates': [[650, 3139], [698, 3139], [787, 3133]],
#      'line_extent': 137,
#      'line_total_characters': 4,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 21,
#      'line_total_base_points': 3,
#      'line_character_density': 34.25,
#      'line_character_per_point': 1.3333333333333333,
#      'baselines_coordinates': {'0': {'extent': 48},
#       '1': {'direct_angle': -8.325650330426836, 'extent': 89},
#       '2': {}},
#      'regular_base_points': True,
#      'point_char_density': 36.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'},
#     '2': {'line_id': 'tr_8_tl_3',
#      'annotation': 'readingOrder {index:2;} textStyle {offset:0; length:5;strikethrough:true;}',
#      'text': '56220',
#      'polygon_coordinates': [[870, 3158],
#       [931, 3151],
#       [954, 3153],
#       [961, 3161],
#       [966, 3156],
#       [986, 3168],
#       [1004, 3158],
#       [1017, 3168],
#       [1057, 3163],
#       [1054, 3070],
#       [1032, 3067],
#       [1004, 3042],
#       [966, 3040],
#       [938, 3062],
#       [916, 3052],
#       [880, 3080],
#       [868, 3080]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 19004.5,
#      'area_estimated_polygon_relative': 0.0004362352875176062,
#      'centroid_polygon': [966.5266121181826, 3107.4417901023444],
#      'line_mean_y': 3139.0,
#      'line_coordinates': [[883, 3133], [972, 3145], [1062, 3139]],
#      'line_extent': 179,
#      'line_total_characters': 5,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 17,
#      'line_total_base_points': 3,
#      'line_character_density': 35.8,
#      'line_character_per_point': 1.6666666666666667,
#      'baselines_coordinates': {'0': {'extent': 89},
#       '1': {'direct_angle': -86.82016988013577, 'extent': 90},
#       '2': {}},
#      'regular_base_points': True,
#      'point_char_density': 53.4,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '2',
#      'annotations': {'0': {'label': 'textStyle',
#        'offset_start': '0',
#        'length': '5',
#        'offset_end': 5,
#        'unicode': '56220'}}},
#     '3': {'line_id': 'tr_8_tl_4',
#      'annotation': 'readingOrder {index:3;}',
#      'text': 'Toole',
#      'polygon_coordinates': [[1223, 3226],
#       [1312, 3206],
#       [1602, 3226],
#       [1660, 3206],
#       [1914, 3198],
#       [1917, 3052],
#       [2042, 2887],
#       [1956, 2831],
#       [1708, 3055],
#       [1665, 3029],
#       [1621, 3063],
#       [1558, 3035],
#       [1664, 2872],
#       [1633, 2841],
#       [1471, 2849],
#       [1314, 2856],
#       [1277, 3042],
#       [1191, 3078]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 210985.5,
#      'area_estimated_polygon_relative': 0.004843027717358832,
#      'centroid_polygon': [1579.4648866075315, 3047.6445877402316],
#      'line_mean_y': 3181.0,
#      'line_coordinates': [[1241, 3181],
#       [1319, 3181],
#       [1408, 3181],
#       [1498, 3181],
#       [1587, 3187],
#       [1677, 3181],
#       [1766, 3181],
#       [1856, 3175]],
#      'line_extent': 615,
#      'line_total_characters': 5,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 18,
#      'line_total_base_points': 8,
#      'line_character_density': 123.0,
#      'line_character_per_point': 0.625,
#      'baselines_coordinates': {'0': {'extent': 78},
#       '1': {'direct_angle': 0.0, 'extent': 89},
#       '2': {'direct_angle': 0.0, 'extent': 90},
#       '3': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '4': {'direct_angle': -85.23635830927383, 'extent': 90},
#       '5': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '6': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '7': {}},
#      'regular_base_points': True,
#      'point_char_density': 142.4,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '3'},
#     '4': {'line_id': 'tr_8_tl_5',
#      'annotation': 'readingOrder {index:4;}',
#      'text': 'Geert',
#      'polygon_coordinates': [[1286, 3557],
#       [1302, 3559],
#       [1298, 3617],
#       [1382, 3552],
#       [1463, 3542],
#       [1496, 3557],
#       [1514, 3547],
#       [1529, 3557],
#       [1579, 3541],
#       [1577, 3438],
#       [1491, 3481],
#       [1466, 3479],
#       [1448, 3463],
#       [1434, 3403],
#       [1409, 3400],
#       [1334, 3461],
#       [1284, 3463]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 32339.5,
#      'area_estimated_polygon_relative': 0.0007423310837262558,
#      'centroid_polygon': [1418.9287867777796, 3502.7098594597937],
#      'line_mean_y': 3533.0,
#      'line_coordinates': [[1301, 3527],
#       [1390, 3533],
#       [1480, 3533],
#       [1563, 3533]],
#      'line_extent': 262,
#      'line_total_characters': 5,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 17,
#      'line_total_base_points': 4,
#      'line_character_density': 52.4,
#      'line_character_per_point': 1.25,
#      'baselines_coordinates': {'0': {'extent': 89},
#       '1': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '2': {'direct_angle': 180.0, 'extent': 83},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 71.2,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '4'}},
#    'region_text': '63635 5119 56220 Toole Geert ',
#    'text_largest': 'Toole',
#    'row_surname': 'Toole',
#    'row_name': '56220',
#    'row_index_numbers': ['63635']},
#   '4': {'region_orientation': '0',
#    'region_type': 'table_header',
#    'identifier': 'TextRegion_1698738733163_28',
#    'reading_order': '154',
#    'structure': 'index',
#    'shape_class': 'Rectangle',
#    'coordinates_list': [['632', '433'],
#     ['864', '433'],
#     ['864', '803'],
#     ['632', '803']],
#    'bbox_height': 370,
#    'bbox_width': 232,
#    'bbox_area': 85840,
#    'bbox_area_relative': 0.001970398436186762,
#    'centroid': [748.0, 618.0],
#    'textlines': {'0': {'line_id': 'tr_3_tl_2',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'Door¬',
#      'polygon_coordinates': [[653, 547],
#       [666, 547],
#       [681, 537],
#       [701, 547],
#       [714, 542],
#       [729, 552],
#       [752, 540],
#       [762, 550],
#       [797, 552],
#       [797, 492],
#       [752, 489],
#       [737, 477],
#       [716, 472],
#       [709, 477],
#       [699, 472],
#       [681, 479],
#       [653, 479]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 9338.0,
#      'area_estimated_polygon_relative': 0.0002143473974500464,
#      'centroid_polygon': [723.2384522024702, 513.5724102234597],
#      'line_mean_y': 526.0,
#      'line_coordinates': [[668, 531], [686, 525], [775, 525], [804, 528]],
#      'line_extent': 136,
#      'line_total_characters': 5,
#      'line_total_punctuation': 1,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 17,
#      'line_total_base_points': 4,
#      'line_character_density': 27.2,
#      'line_character_per_point': 1.25,
#      'baselines_coordinates': {'0': {'extent': 18},
#       '1': {'direct_angle': 4.830419958289941, 'extent': 89},
#       '2': {'direct_angle': 177.13759477388825, 'extent': 29},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 14.4,
#      'text_continuous': True,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'tr_3_tl_4',
#      'annotation': 'readingOrder {index:1;}',
#      'text': 'loopende',
#      'polygon_coordinates': [[638, 631],
#       [684, 623],
#       [711, 641],
#       [747, 613],
#       [774, 615],
#       [812, 638],
#       [830, 633],
#       [827, 545],
#       [800, 540],
#       [777, 552],
#       [749, 540],
#       [721, 565],
#       [636, 550]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 14365.0,
#      'area_estimated_polygon_relative': 0.00032973874109765654,
#      'centroid_polygon': [736.0979347952199, 589.1298178442975],
#      'line_mean_y': 601.6666666666666,
#      'line_coordinates': [[650, 602], [740, 602], [811, 608], [834, 601]],
#      'line_extent': 184,
#      'line_total_characters': 8,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 13,
#      'line_total_base_points': 4,
#      'line_character_density': 23.0,
#      'line_character_per_point': 2.0,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 162.47443162627712, 'extent': 71},
#       '2': {'direct_angle': -164.8459319496874, 'extent': 23},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 45.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'},
#     '2': {'line_id': 'tr_3_tl_7',
#      'annotation': 'readingOrder {index:2;}',
#      'text': 'nummers.',
#      'polygon_coordinates': [[613, 696],
#       [719, 729],
#       [759, 719],
#       [784, 696],
#       [792, 704],
#       [845, 704],
#       [848, 633],
#       [830, 641],
#       [797, 633],
#       [754, 648],
#       [734, 633],
#       [704, 641],
#       [668, 628],
#       [610, 658]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 17036.5,
#      'area_estimated_polygon_relative': 0.0003910611947588044,
#      'centroid_polygon': [729.3971570842994, 675.5012277560924],
#      'line_mean_y': 681.6,
#      'line_coordinates': [[627, 675],
#       [686, 680],
#       [775, 680],
#       [793, 686],
#       [854, 687]],
#      'line_extent': 227,
#      'line_total_characters': 8,
#      'line_total_punctuation': 1,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 14,
#      'line_total_base_points': 5,
#      'line_character_density': 28.375,
#      'line_character_per_point': 1.6,
#      'baselines_coordinates': {'0': {'extent': 59},
#       '1': {'direct_angle': -9.462322208025617, 'extent': 89},
#       '2': {'direct_angle': 175.16958004171005, 'extent': 18},
#       '3': {'direct_angle': -6.632514615138462, 'extent': 61},
#       '4': {}},
#      'regular_base_points': True,
#      'point_char_density': 36.875,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '2'},
#     '3': {'line_id': 'line_1697404007900_10563',
#      'annotation': 'readingOrder {index:3;}',
#      'text': '1',
#      'polygon_coordinates': [[686, 739],
#       [709, 739],
#       [724, 726],
#       [734, 726],
#       [742, 732],
#       [759, 732],
#       [766, 803],
#       [692, 803]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 5155.0,
#      'area_estimated_polygon_relative': 0.00011832949602216635,
#      'centroid_polygon': [726.6353701907533, 767.9503071451664],
#      'line_mean_y': 776.0,
#      'line_coordinates': [[703, 773], [767, 779]],
#      'line_extent': 64,
#      'line_total_characters': 1,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 8,
#      'line_total_base_points': 2,
#      'line_character_density': 64.0,
#      'line_character_per_point': 0.5,
#      'baselines_coordinates': {'0': {'extent': 64}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 128.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '3'}},
#    'header_text': 'Doorloopende nummers. 1 '},
#   '5': {'region_orientation': '0',
#    'region_type': 'table_row',
#    'identifier': 'TextRegion_1697404007449_10557',
#    'reading_order': '157',
#    'structure': 'index',
#    'shape_class': 'Parallelogram',
#    'coordinates_list': [['632', '803'],
#     ['2415', '831'],
#     ['2404', '2363'],
#     ['621', '2335']],
#    'bbox_height': 1560,
#    'bbox_width': 1794,
#    'bbox_area': 2798640,
#    'bbox_area_relative': 0.06424086532443755,
#    'centroid': [1518.0, 1583.0],
#    'textlines': {'0': {'line_id': 'line_1697404007901_10566',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'V.6-2-40 N:o 24 Afwijzing steunverzoek.',
#      'polygon_coordinates': [[628, 803],
#       [1737, 803],
#       [1763, 903],
#       [1455, 893],
#       [1400, 948],
#       [1269, 901],
#       [1150, 943],
#       [1012, 883],
#       [631, 870]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 107784.0,
#      'area_estimated_polygon_relative': 0.0024741079338997433,
#      'centroid_polygon': [1226.576405898216, 853.6046444741335],
#      'line_mean_y': 882.5,
#      'line_coordinates': [[644, 865],
#       [734, 871],
#       [823, 877],
#       [913, 877],
#       [1002, 877],
#       [1092, 883],
#       [1181, 877],
#       [1271, 883],
#       [1360, 883],
#       [1450, 883],
#       [1539, 889],
#       [1629, 895],
#       [1718, 895],
#       [1766, 901]],
#      'line_extent': 1122,
#      'line_total_characters': 39,
#      'line_total_punctuation': 5,
#      'line_total_spaces': 4,
#      'line_total_poly_points': 9,
#      'line_total_base_points': 14,
#      'line_character_density': 28.76923076923077,
#      'line_character_per_point': 2.7857142857142856,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 180.0, 'extent': 89},
#       '2': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '3': {'direct_angle': 180.0, 'extent': 89},
#       '4': {'direct_angle': 80.53767779197439, 'extent': 90},
#       '5': {'direct_angle': -94.76364169072617, 'extent': 89},
#       '6': {'direct_angle': 85.23635830927383, 'extent': 90},
#       '7': {'direct_angle': -99.46232220802563, 'extent': 89},
#       '8': {'direct_angle': 0.0, 'extent': 90},
#       '9': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '10': {'direct_angle': 0.0, 'extent': 90},
#       '11': {'direct_angle': -99.46232220802563, 'extent': 89},
#       '12': {'direct_angle': 171.67434966957316, 'extent': 48},
#       '13': {}},
#      'regular_base_points': True,
#      'point_char_density': 32.30769230769231,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'tr_3_tl_10',
#      'annotation': 'readingOrder {index:1;}',
#      'text': '5118',
#      'polygon_coordinates': [[623, 1569],
#       [666, 1579],
#       [696, 1599],
#       [709, 1599],
#       [721, 1587],
#       [726, 1592],
#       [742, 1584],
#       [774, 1587],
#       [774, 1473],
#       [729, 1476],
#       [701, 1466],
#       [684, 1471],
#       [668, 1486],
#       [658, 1483],
#       [641, 1501],
#       [623, 1498]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 15985.5,
#      'area_estimated_polygon_relative': 0.0003669362092458468,
#      'centroid_polygon': [703.6974237069011, 1531.9712656261404],
#      'line_mean_y': 1557.0,
#      'line_coordinates': [[638, 1557], [728, 1557], [781, 1557]],
#      'line_extent': 143,
#      'line_total_characters': 4,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 16,
#      'line_total_base_points': 3,
#      'line_character_density': 35.75,
#      'line_character_per_point': 1.3333333333333333,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': 180.0, 'extent': 53},
#       '2': {}},
#      'regular_base_points': True,
#      'point_char_density': 67.5,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'},
#     '2': {'line_id': 'tr_3_tl_11',
#      'annotation': 'readingOrder {index:2;}',
#      'text': '56064',
#      'polygon_coordinates': [[870, 1582],
#       [931, 1597],
#       [971, 1574],
#       [999, 1579],
#       [1034, 1604],
#       [1120, 1625],
#       [1110, 1491],
#       [1004, 1463],
#       [994, 1473],
#       [984, 1468],
#       [966, 1478],
#       [954, 1471],
#       [933, 1483],
#       [928, 1478],
#       [890, 1508],
#       [865, 1508]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 28207.5,
#      'area_estimated_polygon_relative': 0.0006474838523851129,
#      'centroid_polygon': [1001.5368784897634, 1539.2520783479572],
#      'line_mean_y': 1571.0,
#      'line_coordinates': [[883, 1563],
#       [972, 1563],
#       [1056, 1575],
#       [1092, 1583]],
#      'line_extent': 209,
#      'line_total_characters': 5,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 16,
#      'line_total_base_points': 4,
#      'line_character_density': 41.8,
#      'line_character_per_point': 1.25,
#      'baselines_coordinates': {'0': {'extent': 89},
#       '1': {'direct_angle': 112.61986494804043, 'extent': 84},
#       '2': {'direct_angle': -175.2363583092738, 'extent': 36},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 71.2,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '2'},
#     '3': {'line_id': 'tr_3_tl_12',
#      'annotation': 'readingOrder {index:3;}',
#      'text': "'t Hart",
#      'polygon_coordinates': [[1158, 1642],
#       [1362, 1642],
#       [1410, 1685],
#       [1471, 1645],
#       [1919, 1680],
#       [2168, 1428],
#       [2129, 1413],
#       [2049, 1380],
#       [1858, 1489],
#       [1810, 1459],
#       [1706, 1239],
#       [1555, 1237],
#       [1418, 1318],
#       [1357, 1389],
#       [1392, 1502],
#       [1311, 1560],
#       [1251, 1561],
#       [1331, 1421],
#       [1243, 1376],
#       [1164, 1439],
#       [1112, 1594]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 264992.0,
#      'area_estimated_polygon_relative': 0.006082709953425005,
#      'centroid_polygon': [1610.1898510143703, 1493.1203822505333],
#      'line_mean_y': 1628.25,
#      'line_coordinates': [[1169, 1617],
#       [1259, 1623],
#       [1348, 1623],
#       [1438, 1623],
#       [1527, 1629],
#       [1617, 1629],
#       [1707, 1629],
#       [1796, 1635],
#       [1886, 1635],
#       [1935, 1644]],
#      'line_extent': 766,
#      'line_total_characters': 7,
#      'line_total_punctuation': 1,
#      'line_total_spaces': 1,
#      'line_total_poly_points': 21,
#      'line_total_base_points': 10,
#      'line_character_density': 109.42857142857143,
#      'line_character_per_point': 0.7,
#      'baselines_coordinates': {'0': {'extent': 90},
#       '1': {'direct_angle': -99.46232220802563, 'extent': 89},
#       '2': {'direct_angle': 0.0, 'extent': 90},
#       '3': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '4': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '5': {'direct_angle': 0.0, 'extent': 90},
#       '6': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '7': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '8': {'direct_angle': 167.61924307119284, 'extent': 49},
#       '9': {}},
#      'regular_base_points': True,
#      'point_char_density': 128.57142857142858,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '3'},
#     '4': {'line_id': 'tr_3_tl_13',
#      'annotation': 'readingOrder {index:4;}',
#      'text': 'Jan',
#      'polygon_coordinates': [[1216, 2125],
#       [1281, 2117],
#       [1327, 2051],
#       [1347, 2033],
#       [1360, 2038],
#       [1367, 2031],
#       [1382, 2036],
#       [1397, 2031],
#       [1435, 2003],
#       [1478, 2005],
#       [1481, 1952],
#       [1440, 1945],
#       [1428, 1950],
#       [1397, 1935],
#       [1372, 1947],
#       [1449, 1862],
#       [1347, 1855],
#       [1282, 1923],
#       [1289, 1973]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 31383.0,
#      'area_estimated_polygon_relative': 0.0007203752810210759,
#      'centroid_polygon': [1348.062002782823, 1978.5877492060458],
#      'line_mean_y': 1996.0,
#      'line_coordinates': [[1301, 2005],
#       [1307, 1999],
#       [1396, 1987],
#       [1486, 1993]],
#      'line_extent': 185,
#      'line_total_characters': 3,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 19,
#      'line_total_base_points': 4,
#      'line_character_density': 61.666666666666664,
#      'line_character_per_point': 0.75,
#      'baselines_coordinates': {'0': {'extent': 6},
#       '1': {'direct_angle': -4.134671373736423, 'extent': 89},
#       '2': {'direct_angle': 86.82016988013577, 'extent': 90},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 8.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '4'}},
#    'region_text': "V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan ",
#    'text_largest': "'t Hart",
#    'row_surname': "'t Hart",
#    'row_name': '56064',
#    'row_index_numbers': ['5118']},
#   '6': {'region_orientation': '0',
#    'region_type': 'table_header',
#    'identifier': 'TextRegion_1698738745652_35',
#    'reading_order': '155',
#    'structure': 'index_military',
#    'shape_class': 'Rectangle',
#    'coordinates_list': [['864', '419'],
#     ['1125', '419'],
#     ['1125', '803'],
#     ['864', '803']],
#    'bbox_height': 384,
#    'bbox_width': 261,
#    'bbox_area': 100224,
#    'bbox_area_relative': 0.002300573309277517,
#    'centroid': [994.5, 611.0],
#    'textlines': {'0': {'line_id': 'line_1696352091736_1372',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'Algemeen',
#      'polygon_coordinates': [[870, 525],
#       [901, 522],
#       [913, 535],
#       [933, 527],
#       [946, 540],
#       [966, 525],
#       [976, 530],
#       [991, 522],
#       [1022, 540],
#       [1049, 527],
#       [1087, 527],
#       [1087, 482],
#       [1006, 474],
#       [961, 449],
#       [870, 464]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 13805.5,
#      'area_estimated_polygon_relative': 0.0003168958016166862,
#      'centroid_polygon': [970.8250214286577, 496.62780534328107],
#      'line_mean_y': 513.0,
#      'line_coordinates': [[885, 513], [1093, 513]],
#      'line_extent': 208,
#      'line_total_characters': 8,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 2,
#      'line_character_density': 26.0,
#      'line_character_per_point': 4.0,
#      'baselines_coordinates': {'0': {'extent': 208}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 52.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'tr_3_tl_3',
#      'annotation': 'readingOrder {index:1;}',
#      'text': 'stamboek',
#      'polygon_coordinates': [[865, 598],
#       [913, 605],
#       [933, 598],
#       [989, 600],
#       [1022, 580],
#       [1080, 583],
#       [1080, 527],
#       [1019, 537],
#       [991, 522],
#       [979, 530],
#       [969, 525],
#       [946, 540],
#       [921, 525],
#       [903, 542],
#       [865, 537]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 13114.0,
#      'area_estimated_polygon_relative': 0.0003010228924994548,
#      'centroid_polygon': [967.2656575669768, 563.602752783285],
#      'line_mean_y': 572.0,
#      'line_coordinates': [[878, 565], [937, 572], [1026, 572], [1086, 572]],
#      'line_extent': 208,
#      'line_total_characters': 8,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 15,
#      'line_total_base_points': 4,
#      'line_character_density': 26.0,
#      'line_character_per_point': 2.0,
#      'baselines_coordinates': {'0': {'extent': 59},
#       '1': {'direct_angle': -13.134022306396323, 'extent': 89},
#       '2': {'direct_angle': 180.0, 'extent': 60},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 29.5,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'},
#     '2': {'line_id': 'tr_3_tl_6',
#      'annotation': 'readingOrder {index:2;}',
#      'text': 'nummer',
#      'polygon_coordinates': [[906, 646],
#       [928, 643],
#       [954, 656],
#       [979, 643],
#       [999, 656],
#       [1006, 648],
#       [1012, 653],
#       [1024, 648],
#       [1032, 656],
#       [1067, 648],
#       [1067, 603],
#       [1047, 600],
#       [1037, 608],
#       [1019, 590],
#       [1006, 593],
#       [989, 585],
#       [981, 593],
#       [906, 585]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 9161.0,
#      'area_estimated_polygon_relative': 0.0002102844836196054,
#      'centroid_polygon': [983.8424662518648, 621.0456645926573],
#      'line_mean_y': 631.0,
#      'line_coordinates': [[920, 629], [972, 638], [984, 632], [1074, 632]],
#      'line_extent': 154,
#      'line_total_characters': 6,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 18,
#      'line_total_base_points': 4,
#      'line_character_density': 25.666666666666668,
#      'line_character_per_point': 1.5,
#      'baselines_coordinates': {'0': {'extent': 52},
#       '1': {'direct_angle': -159.44395478041653, 'extent': 12},
#       '2': {'direct_angle': 4.398705354995532, 'extent': 90},
#       '3': {}},
#      'regular_base_points': True,
#      'point_char_density': 34.666666666666664,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '2'},
#     '3': {'line_id': 'tr_3_tl_8',
#      'annotation': 'readingOrder {index:3;}',
#      'text': 'in Indië',
#      'polygon_coordinates': [[885, 714],
#       [911, 719],
#       [926, 706],
#       [943, 711],
#       [951, 706],
#       [986, 724],
#       [1024, 706],
#       [1064, 716],
#       [1062, 656],
#       [1049, 656],
#       [1032, 643],
#       [996, 658],
#       [984, 646],
#       [961, 656],
#       [943, 648],
#       [923, 653],
#       [916, 646],
#       [906, 653],
#       [883, 653]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 11068.0,
#      'area_estimated_polygon_relative': 0.00025405836313740777,
#      'centroid_polygon': [973.0158113480304, 682.3631339597639],
#      'line_mean_y': 696.6666666666666,
#      'line_coordinates': [[896, 694], [978, 698], [1068, 698]],
#      'line_extent': 172,
#      'line_total_characters': 8,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 1,
#      'line_total_poly_points': 19,
#      'line_total_base_points': 3,
#      'line_character_density': 21.5,
#      'line_character_per_point': 2.6666666666666665,
#      'baselines_coordinates': {'0': {'extent': 82},
#       '1': {'direct_angle': -26.56505117707799, 'extent': 90},
#       '2': {}},
#      'regular_base_points': True,
#      'point_char_density': 30.75,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '3'},
#     '4': {'line_id': 'line_1697404007900_10561',
#      'annotation': 'readingOrder {index:4;}',
#      'text': '2',
#      'polygon_coordinates': [[938, 706],
#       [961, 711],
#       [969, 701],
#       [984, 709],
#       [994, 706],
#       [1004, 711],
#       [1022, 711],
#       [1028, 803],
#       [946, 803]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 7863.5,
#      'area_estimated_polygon_relative': 0.0001805012593540844,
#      'centroid_polygon': [983.2037684661199, 755.3338844026197],
#      'line_mean_y': 773.0,
#      'line_coordinates': [[958, 770], [1032, 776]],
#      'line_extent': 74,
#      'line_total_characters': 1,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 9,
#      'line_total_base_points': 2,
#      'line_character_density': 74.0,
#      'line_character_per_point': 0.5,
#      'baselines_coordinates': {'0': {'extent': 74}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 148.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '4'}},
#    'header_text': 'Algemeen stamboek nummer in Indië 2 '},
#   '7': {'region_orientation': '0',
#    'region_type': 'table_header',
#    'identifier': 'TextRegion_1698738762933_44',
#    'reading_order': '156',
#    'structure': 'name',
#    'shape_class': 'Hexagon',
#    'coordinates_list': [['1125', '422'],
#     ['2226', '422'],
#     ['2418', '455'],
#     ['2422', '810'],
#     ['2226', '803'],
#     ['1125', '803']],
#    'bbox_height': 388,
#    'bbox_width': 1297,
#    'bbox_area': 503236,
#    'bbox_area_relative': 0.011551437877829467,
#    'centroid': [1769.4583035370483, 614.0315107174946],
#    'textlines': {'0': {'line_id': 'tr_3_tl_5',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'NAMEN EN VOORNAMEN.',
#      'polygon_coordinates': [[1286, 638],
#       [2220, 648],
#       [2220, 550],
#       [1286, 550]],
#      'shape_class_polygon': 'Trapezoid',
#      'area_estimated_polygon': 86862.0,
#      'area_estimated_polygon_relative': 0.0019938577465523593,
#      'centroid_polygon': [1761.36917562724, 596.5448028673835],
#      'line_mean_y': 621.8,
#      'line_coordinates': [[1301, 620],
#       [1390, 620],
#       [1480, 620],
#       [1569, 620],
#       [1659, 620],
#       [1748, 620],
#       [1838, 620],
#       [1927, 626],
#       [2017, 626],
#       [2106, 626],
#       [2196, 632],
#       [2226, 632]],
#      'line_extent': 925,
#      'line_total_characters': 19,
#      'line_total_punctuation': 1,
#      'line_total_spaces': 2,
#      'line_total_poly_points': 4,
#      'line_total_base_points': 12,
#      'line_character_density': 48.68421052631579,
#      'line_character_per_point': 1.5833333333333333,
#      'baselines_coordinates': {'0': {'extent': 89},
#       '1': {'direct_angle': 0.0, 'extent': 90},
#       '2': {'direct_angle': 180.0, 'extent': 89},
#       '3': {'direct_angle': 0.0, 'extent': 90},
#       '4': {'direct_angle': 180.0, 'extent': 89},
#       '5': {'direct_angle': 0.0, 'extent': 90},
#       '6': {'direct_angle': 99.46232220802563, 'extent': 89},
#       '7': {'direct_angle': -80.53767779197439, 'extent': 90},
#       '8': {'direct_angle': 180.0, 'extent': 89},
#       '9': {'direct_angle': 80.53767779197439, 'extent': 90},
#       '10': {'direct_angle': -174.28940686250036, 'extent': 30},
#       '11': {}},
#      'regular_base_points': True,
#      'point_char_density': 56.21052631578948,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '0'},
#     '1': {'line_id': 'line_1697404007901_10565',
#      'annotation': 'readingOrder {index:1;}',
#      'text': '3',
#      'polygon_coordinates': [[1710, 729],
#       [1725, 726],
#       [1748, 742],
#       [1758, 737],
#       [1763, 739],
#       [1771, 732],
#       [1793, 732],
#       [1806, 803],
#       [1724, 803]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 5725.0,
#      'area_estimated_polygon_relative': 0.00013141345581511198,
#      'centroid_polygon': [1758.0041048034934, 768.0084716157205],
#      'line_mean_y': 786.5,
#      'line_coordinates': [[1734, 779], [1811, 794]],
#      'line_extent': 77,
#      'line_total_characters': 1,
#      'line_total_punctuation': 0,
#      'line_total_spaces': 0,
#      'line_total_poly_points': 9,
#      'line_total_base_points': 2,
#      'line_character_density': 77.0,
#      'line_character_per_point': 0.5,
#      'baselines_coordinates': {'0': {'extent': 77}, '1': {}},
#      'regular_base_points': True,
#      'point_char_density': 154.0,
#      'text_continuous': False,
#      'annotation_continuous': False,
#      'reading_order': '1'}},
#    'header_text': 'NAMEN EN VOORNAMEN. 3 '},
#   '8': {'region_orientation': '0',
#    'region_type': 'table_header',
#    'identifier': 'TextRegion_1697404226034_10686',
#    'reading_order': '160',
#    'structure': 'family_data',
#    'shape_class': 'Hexagon',
#    'coordinates_list': [['2411', '534'],
#     ['2424', '458'],
#     ['4005', '456'],
#     ['3998', '534'],
#     ['3998', '827'],
#     ['2411', '827']],
#    'bbox_height': 371,
#    'bbox_width': 1594,
#    'bbox_area': 591374,
#    'bbox_area_relative': 0.013574585330865684,
#    'centroid': [3206.252036945856, 642.0649712893852],
#    'textlines': {'0': {'line_id': 'tr_1_tl_1',
#      'annotation': 'readingOrder {index:0;}',
#      'text': 'Namen der ouders, geboorteplaats, datum van geboorte,',
#      'polygon_coordinates': [[2606, 623],
#       [3842, 615],
#       [3842, 537],
#       [3701, 515],
#       [3476, 552],
#       [3007, 497],
#       [2903, 545],
#       [2606, 522]],
#      'shape_class_polygon': 'Complex Polygon',
#      'area_estimated_polygon': 112256.5,
#      'area_estimated_polygon_relative': 0.002576771109643514,
#      'centroid_polygon': [3208.5921810021396, 572.6836872103917],
#      'line_mean_y': 593.2307692307693,
#      'line_coordinates': [[2620, 584],
#       [2709, 590],
#       [2799, 590],
#       [2888, 590],
#       [2978, 590],
#       [3067, 596],
#       [3157, 590],
#       [3246, 596],
#       [3336, 596],
#       [3425, 590],
#       [3515, 590],
#       [3605, 596],
#       [3694, 596],
#       [3784, 602],
# ...
#     [5388, 5485],
#     [4203, 5485]]},
#   '44': {'identifier': 'r_45',
#    'reading_order': ['46'],
#    'coordinates_list': [[3029, 5430],
#     [3228, 5430],
#     [3228, 5435],
#     [3029, 5435]]},
#   '45': {'identifier': 'r_46',
#    'reading_order': ['47'],
#    'coordinates_list': [[1483, 5430],
#     [3015, 5430],
#     [3015, 5452],
#     [1483, 5452]]},
#   '46': {'identifier': 'r_47',
#    'reading_order': ['48'],
#    'coordinates_list': [[611, 5426], [1508, 5426], [1508, 5436], [611, 5436]]},
#   '47': {'identifier': 'r_48',
#    'reading_order': ['49'],
#    'coordinates_list': [[5405, 5464],
#     [6218, 5464],
#     [6218, 5478],
#     [5405, 5478]]},
#   '48': {'identifier': 'r_49',
#    'reading_order': ['50'],
#    'coordinates_list': [[6260, 5475],
#     [6546, 5475],
#     [6546, 5482],
#     [6260, 5482]]},
#   '49': {'identifier': 'r_50',
#    'reading_order': ['51'],
#    'coordinates_list': [[3542, 5460],
#     [4013, 5460],
#     [4013, 5475],
#     [3542, 5475]]},
#   '50': {'identifier': 'r_51',
#    'reading_order': ['52'],
#    'coordinates_list': [[5394, 5474],
#     [5589, 5474],
#     [5589, 5492],
#     [5394, 5492]]},
#   '51': {'identifier': 'r_52',
#    'reading_order': ['53'],
#    'coordinates_list': [[5626, 5476],
#     [6130, 5476],
#     [6130, 5501],
#     [5626, 5501]]},
#   '52': {'identifier': 'r_53',
#    'reading_order': ['54'],
#    'coordinates_list': [[6163, 5484],
#     [6615, 5484],
#     [6615, 5506],
#     [6163, 5506]]},
#   '53': {'identifier': 'r_54',
#    'reading_order': ['55'],
#    'coordinates_list': [[6735, 5488],
#     [7262, 5488],
#     [7262, 5513],
#     [6735, 5513]]},
#   '54': {'identifier': 'r_55',
#    'reading_order': ['56'],
#    'coordinates_list': [[1625, 5708],
#     [2395, 5708],
#     [2395, 5731],
#     [1625, 5731]]},
#   '55': {'identifier': 'r_56',
#    'reading_order': ['57'],
#    'coordinates_list': [[2395, 5724],
#     [2628, 5724],
#     [2628, 5733],
#     [2395, 5733]]},
#   '56': {'identifier': 'r_57',
#    'reading_order': ['58'],
#    'coordinates_list': [[911, 5715], [1438, 5715], [1438, 5731], [911, 5731]]},
#   '57': {'identifier': 'r_58',
#    'reading_order': ['59'],
#    'coordinates_list': [[583, 1118], [601, 1118], [601, 1366], [583, 1366]]},
#   '58': {'identifier': 'r_59',
#    'reading_order': ['60'],
#    'coordinates_list': [[581, 1880], [599, 1880], [599, 2168], [581, 2168]]},
#   '59': {'identifier': 'r_60',
#    'reading_order': ['61'],
#    'coordinates_list': [[578, 2440], [600, 2440], [600, 3361], [578, 3361]]},
#   '60': {'identifier': 'r_61',
#    'reading_order': ['62'],
#    'coordinates_list': [[579, 3610], [597, 3610], [597, 3863], [579, 3863]]},
#   '61': {'identifier': 'r_62',
#    'reading_order': ['63'],
#    'coordinates_list': [[606, 438], [613, 438], [613, 1365], [606, 1365]]},
#   '62': {'identifier': 'r_63',
#    'reading_order': ['64'],
#    'coordinates_list': [[580, 4677], [599, 4677], [599, 4923], [580, 4923]]},
#   '63': {'identifier': 'r_64',
#    'reading_order': ['65'],
#    'coordinates_list': [[579, 5061], [598, 5061], [598, 5273], [579, 5273]]},
#   '64': {'identifier': 'r_65',
#    'reading_order': ['66'],
#    'coordinates_list': [[602, 1559], [611, 1559], [611, 3006], [602, 3006]]},
#   '65': {'identifier': 'r_66',
#    'reading_order': ['67'],
#    'coordinates_list': [[602, 3176], [609, 3176], [609, 4493], [602, 4493]]},
#   '66': {'identifier': 'r_67',
#    'reading_order': ['68'],
#    'coordinates_list': [[603, 4493], [611, 4493], [611, 4883], [603, 4883]]},
#   '67': {'identifier': 'r_68',
#    'reading_order': ['69'],
#    'coordinates_list': [[599, 5076], [608, 5076], [608, 5401], [599, 5401]]},
#   '68': {'identifier': 'r_69',
#    'reading_order': ['70'],
#    'coordinates_list': [[859, 860], [864, 860], [864, 1654], [859, 1654]]},
#   '69': {'identifier': 'r_70',
#    'reading_order': ['71'],
#    'coordinates_list': [[861, 683], [865, 683], [865, 827], [861, 827]]},
#   '70': {'identifier': 'r_71',
#    'reading_order': ['72'],
#    'coordinates_list': [[858, 1836], [865, 1836], [865, 2334], [858, 2334]]},
#   '71': {'identifier': 'r_72',
#    'reading_order': ['73'],
#    'coordinates_list': [[855, 2349], [862, 2349], [862, 3030], [855, 3030]]},
#   '72': {'identifier': 'r_73',
#    'reading_order': ['74'],
#    'coordinates_list': [[854, 3269], [861, 3269], [861, 3877], [854, 3877]]},
#   '73': {'identifier': 'r_74',
#    'reading_order': ['75'],
#    'coordinates_list': [[854, 3889], [861, 3889], [861, 4706], [854, 4706]]},
#   '74': {'identifier': 'r_75',
#    'reading_order': ['76'],
#    'coordinates_list': [[852, 4710], [862, 4710], [862, 5400], [852, 5400]]},
#   '75': {'identifier': 'r_76',
#    'reading_order': ['77'],
#    'coordinates_list': [[1113, 1303],
#     [1121, 1303],
#     [1121, 1595],
#     [1113, 1595]]},
#   '76': {'identifier': 'r_77',
#    'reading_order': ['78'],
#    'coordinates_list': [[1112, 1615],
#     [1119, 1615],
#     [1119, 2336],
#     [1112, 2336]]},
#   '77': {'identifier': 'r_78',
#    'reading_order': ['79'],
#    'coordinates_list': [[1108, 2352],
#     [1118, 2352],
#     [1118, 3880],
#     [1108, 3880]]},
#   '78': {'identifier': 'r_79',
#    'reading_order': ['80'],
#    'coordinates_list': [[1110, 3892],
#     [1117, 3892],
#     [1117, 4609],
#     [1110, 4609]]},
#   '79': {'identifier': 'r_80',
#    'reading_order': ['81'],
#    'coordinates_list': [[1108, 4627],
#     [1115, 4627],
#     [1115, 5407],
#     [1108, 5407]]},
#   '80': {'identifier': 'r_81',
#    'reading_order': ['82'],
#    'coordinates_list': [[1908, 820], [1913, 820], [1913, 1096], [1908, 1096]]},
#   '81': {'identifier': 'r_82',
#    'reading_order': ['83'],
#    'coordinates_list': [[1907, 1122],
#     [1914, 1122],
#     [1914, 1537],
#     [1907, 1537]]},
#   '82': {'identifier': 'r_83',
#    'reading_order': ['84'],
#    'coordinates_list': [[1906, 1576],
#     [1912, 1576],
#     [1912, 1926],
#     [1906, 1926]]},
#   '83': {'identifier': 'r_84',
#    'reading_order': ['85'],
#    'coordinates_list': [[1905, 1958],
#     [1910, 1958],
#     [1910, 2344],
#     [1905, 2344]]},
#   '84': {'identifier': 'r_85',
#    'reading_order': ['86'],
#    'coordinates_list': [[1903, 2357],
#     [1911, 2357],
#     [1911, 3874],
#     [1903, 3874]]},
#   '85': {'identifier': 'r_86',
#    'reading_order': ['87'],
#    'coordinates_list': [[1905, 3898],
#     [1912, 3898],
#     [1912, 4129],
#     [1905, 4129]]},
#   '86': {'identifier': 'r_87',
#    'reading_order': ['88'],
#    'coordinates_list': [[1906, 4166],
#     [1910, 4166],
#     [1910, 4250],
#     [1906, 4250]]},
#   '87': {'identifier': 'r_88',
#    'reading_order': ['89'],
#    'coordinates_list': [[1901, 5023],
#     [1909, 5023],
#     [1909, 5414],
#     [1901, 5414]]},
#   '88': {'identifier': 'r_89',
#    'reading_order': ['90'],
#    'coordinates_list': [[2408, 912], [2425, 912], [2425, 1420], [2408, 1420]]},
#   '89': {'identifier': 'r_90',
#    'reading_order': ['91'],
#    'coordinates_list': [[2405, 1680],
#     [2424, 1680],
#     [2424, 2131],
#     [2405, 2131]]},
#   '90': {'identifier': 'r_91',
#    'reading_order': ['92'],
#    'coordinates_list': [[2404, 2131],
#     [2413, 2131],
#     [2413, 2312],
#     [2404, 2312]]},
#   '91': {'identifier': 'r_92',
#    'reading_order': ['93'],
#    'coordinates_list': [[2403, 2407],
#     [2410, 2407],
#     [2410, 2608],
#     [2403, 2608]]},
#   '92': {'identifier': 'r_93',
#    'reading_order': ['94'],
#    'coordinates_list': [[2403, 2608],
#     [2422, 2608],
#     [2422, 2911],
#     [2403, 2911]]},
#   '93': {'identifier': 'r_94',
#    'reading_order': ['95'],
#    'coordinates_list': [[2418, 1420],
#     [2426, 1420],
#     [2426, 1570],
#     [2418, 1570]]},
#   '94': {'identifier': 'r_95',
#    'reading_order': ['96'],
#    'coordinates_list': [[2403, 3357],
#     [2423, 3357],
#     [2423, 3645],
#     [2403, 3645]]},
#   '95': {'identifier': 'r_96',
#    'reading_order': ['97'],
#    'coordinates_list': [[2426, 530], [2428, 530], [2428, 627], [2426, 627]]},
#   '96': {'identifier': 'r_97',
#    'reading_order': ['98'],
#    'coordinates_list': [[2424, 661], [2427, 661], [2427, 801], [2424, 801]]},
#   '97': {'identifier': 'r_98',
#    'reading_order': ['99'],
#    'coordinates_list': [[2401, 3921],
#     [2412, 3921],
#     [2412, 4167],
#     [2401, 4167]]},
#   '98': {'identifier': 'r_99',
#    'reading_order': ['100'],
#    'coordinates_list': [[2402, 4167],
#     [2419, 4167],
#     [2419, 4533],
#     [2402, 4533]]},
#   '99': {'identifier': 'r_100',
#    'reading_order': ['101'],
#    'coordinates_list': [[2412, 2911],
#     [2423, 2911],
#     [2423, 3062],
#     [2412, 3062]]},
#   '100': {'identifier': 'r_101',
#    'reading_order': ['102'],
#    'coordinates_list': [[2400, 4821],
#     [2419, 4821],
#     [2419, 5169],
#     [2400, 5169]]},
#   '101': {'identifier': 'r_102',
#    'reading_order': ['103'],
#    'coordinates_list': [[2399, 5258],
#     [2407, 5258],
#     [2407, 5394],
#     [2399, 5394]]},
#   '102': {'identifier': 'r_103',
#    'reading_order': ['104'],
#    'coordinates_list': [[2415, 3175],
#     [2423, 3175],
#     [2423, 3357],
#     [2415, 3357]]},
#   '103': {'identifier': 'r_104',
#    'reading_order': ['105'],
#    'coordinates_list': [[3408, 980], [3416, 980], [3416, 1134], [3408, 1134]]},
#   '104': {'identifier': 'r_105',
#    'reading_order': ['106'],
#    'coordinates_list': [[3407, 1134],
#     [3427, 1134],
#     [3427, 1452],
#     [3407, 1452]]},
#   '105': {'identifier': 'r_106',
#    'reading_order': ['107'],
#    'coordinates_list': [[3404, 2000],
#     [3417, 2000],
#     [3417, 2201],
#     [3404, 2201]]},
#   '106': {'identifier': 'r_107',
#    'reading_order': ['108'],
#    'coordinates_list': [[3407, 1760],
#     [3424, 1760],
#     [3424, 1955],
#     [3407, 1955]]},
#   '107': {'identifier': 'r_108',
#    'reading_order': ['109'],
#    'coordinates_list': [[3405, 2631],
#     [3412, 2631],
#     [3412, 2814],
#     [3405, 2814]]},
#   '108': {'identifier': 'r_109',
#    'reading_order': ['110'],
#    'coordinates_list': [[3399, 3949],
#     [3410, 3949],
#     [3410, 4202],
#     [3399, 4202]]},
#   '109': {'identifier': 'r_110',
#    'reading_order': ['111'],
#    'coordinates_list': [[3399, 4202],
#     [3420, 4202],
#     [3420, 4526],
#     [3399, 4526]]},
#   '110': {'identifier': 'r_111',
#    'reading_order': ['112'],
#    'coordinates_list': [[3418, 1657],
#     [3426, 1657],
#     [3426, 1760],
#     [3418, 1760]]},
#   '111': {'identifier': 'r_112',
#    'reading_order': ['113'],
#    'coordinates_list': [[3395, 4855],
#     [3417, 4855],
#     [3417, 5406],
#     [3395, 5406]]},
#   '112': {'identifier': 'r_113',
#    'reading_order': ['114'],
#    'coordinates_list': [[3408, 4688],
#     [3419, 4688],
#     [3419, 4855],
#     [3408, 4855]]},
#   '113': {'identifier': 'r_114',
#    'reading_order': ['115'],
#    'coordinates_list': [[3413, 4526],
#     [3420, 4526],
#     [3420, 4641],
#     [3413, 4641]]},
#   '114': {'identifier': 'r_115',
#    'reading_order': ['116'],
#    'coordinates_list': [[4018, 470], [4031, 470], [4031, 1564], [4018, 1564]]},
#   '115': {'identifier': 'r_116',
#    'reading_order': ['117'],
#    'coordinates_list': [[4004, 1569],
#     [4026, 1569],
#     [4026, 5412],
#     [4004, 5412]]},
#   '116': {'identifier': 'r_117',
#    'reading_order': ['118'],
#    'coordinates_list': [[4122, 2597],
#     [4133, 2597],
#     [4133, 2834],
#     [4122, 2834]]},
#   '117': {'identifier': 'r_118',
#    'reading_order': ['119'],
#    'coordinates_list': [[4126, 2377],
#     [4134, 2377],
#     [4134, 2537],
#     [4126, 2537]]},
#   '118': {'identifier': 'r_119',
#    'reading_order': ['120'],
#    'coordinates_list': [[4122, 2915],
#     [4131, 2915],
#     [4131, 3075],
#     [4122, 3075]]},
#   '119': {'identifier': 'r_120',
#    'reading_order': ['121'],
#    'coordinates_list': [[4197, 2346],
#     [4217, 2346],
#     [4217, 3895],
#     [4197, 3895]]},
#   '120': {'identifier': 'r_121',
#    'reading_order': ['122'],
#    'coordinates_list': [[4222, 474], [4240, 474], [4240, 2348], [4222, 2348]]},
#   '121': {'identifier': 'r_122',
#    'reading_order': ['123'],
#    'coordinates_list': [[4203, 3905],
#     [4223, 3905],
#     [4223, 5421],
#     [4203, 5421]]},
#   '122': {'identifier': 'r_123',
#    'reading_order': ['124'],
#    'coordinates_list': [[5879, 2377],
#     [5898, 2377],
#     [5898, 3917],
#     [5879, 3917]]},
#   '123': {'identifier': 'r_124',
#    'reading_order': ['125'],
#    'coordinates_list': [[5901, 861], [5908, 861], [5908, 2370], [5901, 2370]]},
#   '124': {'identifier': 'r_125',
#    'reading_order': ['126'],
#    'coordinates_list': [[5906, 496], [5910, 496], [5910, 842], [5906, 842]]},
#   '125': {'identifier': 'r_126',
#    'reading_order': ['127'],
#    'coordinates_list': [[5883, 3929],
#     [5904, 3929],
#     [5904, 5459],
#     [5883, 5459]]},
#   '126': {'identifier': 'r_127',
#    'reading_order': ['128'],
#    'coordinates_list': [[6922, 2396],
#     [6935, 2396],
#     [6935, 3926],
#     [6922, 3926]]},
#   '127': {'identifier': 'r_128',
#    'reading_order': ['129'],
#    'coordinates_list': [[6941, 509], [6951, 509], [6951, 2384], [6941, 2384]]},
#   '128': {'identifier': 'r_129',
#    'reading_order': ['130'],
#    'coordinates_list': [[6925, 3959],
#     [6939, 3959],
#     [6939, 5479],
#     [6925, 5479]]},
#   '129': {'identifier': 'r_130',
#    'reading_order': ['131'],
#    'coordinates_list': [[7616, 2394],
#     [7633, 2394],
#     [7633, 3935],
#     [7616, 3935]]},
#   '130': {'identifier': 'r_131',
#    'reading_order': ['132'],
#    'coordinates_list': [[7640, 592], [7648, 592], [7648, 1508], [7640, 1508]]},
#   '131': {'identifier': 'r_132',
#    'reading_order': ['133'],
#    'coordinates_list': [[7637, 1540],
#     [7645, 1540],
#     [7645, 2387],
#     [7637, 2387]]},
#   '132': {'identifier': 'r_133',
#    'reading_order': ['134'],
#    'coordinates_list': [[7625, 2393],
#     [7653, 2393],
#     [7653, 3961],
#     [7625, 3961]]},
#   '133': {'identifier': 'r_134',
#    'reading_order': ['135'],
#    'coordinates_list': [[7620, 3971],
#     [7632, 3971],
#     [7632, 5494],
#     [7620, 5494]]},
#   '134': {'identifier': 'r_135',
#    'reading_order': ['136'],
#    'coordinates_list': [[7643, 583], [7669, 583], [7669, 2393], [7643, 2393]]},
#   '135': {'identifier': 'r_136',
#    'reading_order': ['137'],
#    'coordinates_list': [[7632, 3971],
#     [7652, 3971],
#     [7652, 4846],
#     [7632, 4846]]},
#   '136': {'identifier': 'r_137',
#    'reading_order': ['138'],
#    'coordinates_list': [[7630, 4891],
#     [7646, 4891],
#     [7646, 5517],
#     [7630, 5517]]},
#   '137': {'identifier': 'r_138',
#    'reading_order': ['139'],
#    'coordinates_list': [[7996, 406], [8051, 406], [8051, 5538], [7996, 5538]]},
#   '138': {'identifier': 'r_139',
#    'reading_order': ['140'],
#    'coordinates_list': [[8042, 308], [8051, 308], [8051, 468], [8042, 468]]},
#   '139': {'identifier': 'r_140',
#    'reading_order': ['141'],
#    'coordinates_list': [[8037, 5010],
#     [8045, 5010],
#     [8045, 5154],
#     [8037, 5154]]},
#   '140': {'identifier': 'r_141',
#    'reading_order': ['142'],
#    'coordinates_list': [[3888, 1119],
#     [3963, 1119],
#     [3963, 1122],
#     [3888, 1122]]},
#   '141': {'identifier': 'r_142',
#    'reading_order': ['143'],
#    'coordinates_list': [[3899, 3720],
#     [3946, 3720],
#     [3946, 3723],
#     [3899, 3723]]},
#   '142': {'identifier': 'r_143',
#    'reading_order': ['144'],
#    'coordinates_list': [[3900, 4357],
#     [3937, 4357],
#     [3937, 4360],
#     [3900, 4360]]},
#   '143': {'identifier': 'r_144',
#    'reading_order': ['145'],
#    'coordinates_list': [[1520, 5414],
#     [1737, 5414],
#     [1737, 5418],
#     [1520, 5418]]},
#   '144': {'identifier': 'r_145',
#    'reading_order': ['146'],
#    'coordinates_list': [[2908, 5427],
#     [3026, 5427],
#     [3026, 5432],
#     [2908, 5432]]},
#   '145': {'identifier': 'r_146',
#    'reading_order': ['147'],
#    'coordinates_list': [[982, 5728], [1028, 5728], [1028, 5731], [982, 5731]]},
#   '146': {'identifier': 'r_147',
#    'reading_order': ['148'],
#    'coordinates_list': [[855, 3890], [861, 3890], [861, 3954], [855, 3954]]},
#   '147': {'identifier': 'r_148',
#    'reading_order': ['149'],
#    'coordinates_list': [[1116, 460], [1121, 460], [1121, 769], [1116, 769]]},
#   '148': {'identifier': 'r_149',
#    'reading_order': ['150'],
#    'coordinates_list': [[3405, 2582],
#     [3408, 2582],
#     [3408, 2627],
#     [3405, 2627]]},
#   '149': {'identifier': 'r_150',
#    'reading_order': ['151'],
#    'coordinates_list': [[3405, 2720],
#     [3413, 2720],
#     [3413, 2801],
#     [3405, 2801]]},
#   '150': {'identifier': 'r_151',
#    'reading_order': ['152'],
#    'coordinates_list': [[4023, 2102],
#     [4024, 2102],
#     [4024, 2216],
#     [4023, 2216]]}}}

# %%
allowed_structures = [
    'index_military',
    'name',
    'family_data',
    'muster_data',
    'campaign_data',
    'comments',
]

# %%
def preprocess(element, prefix=''):
    prefix_add = '  '
    if isinstance(element, dict):
        if 'structure' in element:
            print(prefix + 'structure: ' + element['structure'])
        if 'text' in element:
            print(prefix + element['text'])
        if 'region_text' in element:
            print(prefix + 'region_text: ' + element['region_text'])
        if 'row_surname' in element:
            print(prefix + 'row_surname: ' + element['row_surname'])
        if 'row_name' in element:
            print(prefix + 'row_name: ' + element['row_name'])

        for key, value in element.items():
            preprocess(value, prefix + prefix_add + '- ')
    elif isinstance(element, list):
        # print('parent:')
        for item in element:
            preprocess(item, prefix + prefix_add)
    else:
        pass

# %%
hello = preprocess(data)
# Out:
#   -   - structure: index
#   -   - region_text: 5118
#   -   - row_surname: 5118
#   -   -   -   - 5118
#   -   - structure: page_number
#   -   - region_text: 1707
#   -   -   -   - 1707
#   -   - structure: index
#   -   - region_text: J.J. Montagne 5120 Montagne Johannes, Jacobus V. P.
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - J.J. Montagne
#   -   -   -   - 5120
#   -   -   -   - Montagne
#   -   -   -   - Johannes, Jacobus
#   -   -   -   - V. P.
#   -   - structure: index
#   -   - region_text: 63635 5119 56220 Toole Geert
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - 63635
#   -   -   -   - 5119
#   -   -   -   - 56220
#   -   -   -   - Toole
#   -   -   -   - Geert
#   -   - structure: index
#   -   -   -   - Door¬
#   -   -   -   - loopende
#   -   -   -   - nummers.
#   -   -   -   - 1
#   -   - structure: index
#   -   - region_text: V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - V.6-2-40 N:o 24 Afwijzing steunverzoek.
#   -   -   -   - 5118
#   -   -   -   - 56064
#   -   -   -   - 't Hart
#   -   -   -   - Jan
#   -   - structure: index_military
#   -   -   -   - Algemeen
#   -   -   -   - stamboek
#   -   -   -   - nummer
#   -   -   -   - in Indië
#   -   -   -   - 2
#   -   - structure: name
#   -   -   -   - NAMEN EN VOORNAMEN.
#   -   -   -   - 3
#   -   - structure: family_data
#   -   -   -   - Namen der ouders, geboorteplaats, datum van geboorte,
#   -   -   -   - laatste woonplaats en signalement.
#   -   -   -   - 4
#   -   - structure: family_data
#   -   - region_text: Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter.
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - Vader
#   -   -   -   - Jan
#   -   -   -   - Moeder
#   -   -   -   - Catharina van Bemmel
#   -   -   -   - Geboren te
#   -   -   -   - Leiderdorp /Z.H.
#   -   -   -   - den
#   -   -   -   - 12:e November 1883
#   -   -   -   - Laatst gewoond te
#   -   -   -   - Rotterdam
#   -   -   -   - Bij zijne aankomst bij het korps
#   -   -   -   - lang 1:667 Meter.
#   -   - structure: family_data
#   -   - region_text: Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - Vader
#   -   -   -   - Hendrik
#   -   -   -   - Moeder
#   -   -   -   - Jantje Baptist
#   -   -   -   - Geboren te
#   -   -   -   - Borger (Drenthe)
#   -   -   -   - den
#   -   -   -   - 15 Augustus 1875
#   -   -   -   - Laatst gewoond te Borger
#   -   -   -   - Bij zijne aankomst bij het korp
#   -   -   -   - lang
#   -   -   -   - 1.708 Meter
#   -   - structure: family_data
#   -   - region_text: Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - Vader
#   -   -   -   - Johannes
#   -   -   -   - Moeder
#   -   -   -   - Jannetje van der
#   -   -   -   - Meer
#   -   -   -   - Geboren te
#   -   -   -   - Leiden (Zuid-Holl:d.)
#   -   -   -   - 30:en Januari 1862
#   -   -   -   - den
#   -   -   -   - Laatst gewoond te
#   -   -   -   - Leiden
#   -   -   -   - Bij zijne aankomst bij het korps
#   -   -   -   - lang 1.563 Meter.
#   -   -   -   - Gehuwd
#   -   - structure: family_data
#   -   - region_text: Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - Haar
#   -   -   -   - Kin
#   -   -   -   - Aangezicht
#   -   -   -   - Ovaal
#   -   -   -   - Voorhoofd
#   -   -   -   - smal
#   -   -   -   - Oogen
#   -   -   -   - bruin
#   -   -   -   - Neus
#   -   -   -   - gewoon
#   -   -   -   - Mond
#   -   -   -   - id
#   -   -   -   - rond
#   -   -   -   - blond
#   -   -   -   - Wenkbrauwen
#   -   -   -   - id
#   -   -   -   - Merkbare teekenen  „
#   -   - structure: family_data
#   -   - region_text: Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - Aangezicht
#   -   -   -   - ovaal
#   -   -   -   - Voorhoofd
#   -   -   -   - hoog
#   -   -   -   - Oogen
#   -   -   -   - blauw
#   -   -   -   - Neus
#   -   -   -   - gewoon
#   -   -   -   - Mond
#   -   -   -   - klein
#   -   -   -   - Kin
#   -   -   -   - rond
#   -   -   -   - Haar
#   -   -   -   - bruin
#   -   -   -   - Wenkbrauwen
#   -   -   -   - id
#   -   -   -   - Merkbare teekenen „
#   -   - structure: family_data
#   -   - region_text: Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen litteeken aan den hals
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - Aangezicht
#   -   -   -   - rond
#   -   -   -   - Voorhoofd
#   -   -   -   - gewoon
#   -   -   -   - Oogen
#   -   -   -   - grijs
#   -   -   -   - Neus
#   -   -   -   - gewoon
#   -   -   -   - Mond
#   -   -   -   - klein
#   -   -   -   - Kin
#   -   -   -   - rond
#   -   -   -   - Haar
#   -   -   -   - blond
#   -   -   -   - Wenkbrauwen
#   -   -   -   - id
#   -   -   -   - Merkbare teekenen
#   -   -   -   - littee¬
#   -   -   -   - ken aan den hals
#   -   - structure: muster_data
#   -   - region_text: 2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in 's Rijkspostspaarbank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uitdrukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een affaire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze militair zes jaren onafgebroken in Ned. Indië zal hebben doorgebracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - 2 December 1901
#   -   -   -   - Vrijwillig geengageerd als soldaat voor zes jaren bij het
#   -   -   -   - leger zoowel in als buiten Europa met ƒ300 - premie
#   -   -   -   - waarvan f 50 - uitbetaald en ƒ 250 - in 's Rijkspostspaar¬
#   -   -   -   - bank ingelegd is
#   -   -   -   - Gedetacheerd naar Oost-Indië en op dato te Amsterdam over¬
#   -   -   -   - 25 October 1902
#   -   -   -   - gegaan aan boord van het SS„ Prins Hendrik"
#   -   -   -   - 1 December 1902
#   -   -   -   - Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on
#   -   -   -   - 5 Mei 1903
#   -   -   -   - Overgegaan bij het 5 Bat:on Inf:ie
#   -   -   -   - 4 Juli 1905
#   -   -   -   - „  „ „ strafdetachement (bewak: det:t)
#   -   -   -   - „  „ „ 5 Bat:en Int:ie
#   -   -   -   - 26 October 1905
#   -   -   -   - Voor der krijgsraad te Magelang en op dato in preventie
#   -   -   -   - 16 April 1906
#   -   -   -   - hechtenis. Bij vonnis van dien krijgsraad dd. 27 April
#   -   -   -   - 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei
#   -   -   -   - 1906 ingaande vf. dien datum veroordeeld tot een jaar
#   -   -   -   - militaire gevangenisstraf wegens het als minder militaire uit¬
#   -   -   -   - drukkelijk weigeren en opzettelijk nalaten, de orders van
#   -   -   -   - dengenen die boven hem gesteld is, te gehoorzamen en
#   -   -   -   - na te komen in eene andere gelegenheid der in een af¬
#   -   -   -   - faire tegen den vijand of in eene plaats welke dadelijk
#   -   -   -   - belegerd of bekend is
#   -   -   -   - 1 Juni 1906
#   -   -   -   - ter executie gelegd.
#   -   -   -   - 18 Mei 1907
#   -   -   -   - Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en
#   -   -   -   - Overgegaan bij het 5 Bat:en Inf:ie
#   -   -   -   - 5 October 1907
#   -   -   -   - 28 December 1907
#   -   -   -   - „  „  „ 9:' „  „
#   -   -   -   - 10 Juli 1908
#   -   -   -   - Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze mi¬
#   -   -   -   - litair zes jaren onafgebroken in Ned. Indië zal hebben doorge¬
#   -   -   -   - bracht, gerekend van en met den dag van inscheping herwaerts
#   -   -   -   - naar Nederland te worden opgezonden
#   -   - structure: muster_data
#   -   - region_text: 6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - 6 December 1901
#   -   -   -   - 6 „ 1902
#   -   -   -   - 6 Juni 1903
#   -   -   -   - 6 - „ 1904
#   -   -   -   - 6 - „ 1905
#   -   -   -   - 31 Augustus 1905
#   -   -   -   - 6 Juni 1906
#   -   -   -   - 4 „ 1907
#   -   -   -   - Zie Suppletie folio 33143 33143
#   -   -   -   - Vrijwillig geengageerd als soldaat voor een jaar
#   -   -   -   - bij het vaste personeel van de Reconvalescenten afdeeling
#   -   -   -   - Gereëngageerd voor zes maanden.
#   -   -   -   - Gereëngageerd voor een jaar
#   -   -   -   - Gereëngeerd voor een jaar
#   -   -   -   - Gereëngageerd voor een jaar
#   -   -   -   - Korporaal
#   -   -   -   - Opnieuw verbonden voor een jaar
#   -   -   -   - Idem  „ een jaar
#   -   - structure: muster_data
#   -   - region_text: Model n°. 178 (binnenvel) Art. 319, § 1. April 1899
#   -   -   -   - Model n°. 178 (binnenvel) Art. 319, § 1.
#   -   -   -   - April 1899
#   -   - structure: muster_data
#   -   -   -   - Waar — hetzij binnen- of buitenslands — en wanneer in dienst getreden ;
#   -   -   -   - omschrijving van het aangegaan akkoord, en de verdere militaire loopbaan.
#   -   -   -   - 5
#   -   - structure: muster_data
#   -   - region_text: xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amsterdam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - xx
#   -   -   -   - Toole N:o 5119.
#   -   -   -   - 18 april 1908
#   -   -   -   - Gedetacheerd naar Oost-Indië en op dato te Amster¬
#   -   -   -   - dam overgegaan dan boord van het SS„ Oranje”
#   -   -   -   - 23 Mei 1908
#   -   -   -   - Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat:
#   -   -   -   - 26 Augustus 1908
#   -   -   -   - Overgegaan bij het 18:' Bat:on Inf:ie
#   -   -   -   - 5Juni 1909
#   -   -   -   - Bestemd om naar Nederland te worden opgezonden daar
#   -   -   -   - zijn gezondheidstoestand dit noodig maakt
#   -   -   -   - 10 „ 1909
#   -   -   -   - ter opzending naar Nederland overgegaan bij het Subskader te Batavia
#   -   -   -   - 17 „ 1909
#   -   -   -   - derwaarts vertrokken met het SS„ Koning Willem I”
#   -   -   -   - 21 Juli 1909
#   -   -   -   - Ontscheept te Amsterdam en op dato terug in de sterkte van het korps
#   -   - structure: campaign_data
#   -   - region_text: V 2/2'50 N:o 6 dupl. pens. akte verstrekt.
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - V 2/2'50 N:o 6 dupl. pens. akte verstrekt.
#   -   - structure: campaign_data
#   -   - region_text: 27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle militaire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdurend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan 	ƒ‎ 12.50 uitbetaald en 	ƒ‎ 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt bevonden wordt voor de actieven dienst.
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - 27 Mei 1911 Uit de sterkte gebracht, zijnde aan
#   -   -   -   - hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens
#   -   -   -   - voortdurende ongeschiktheid voor alle mili¬
#   -   -   -   - taire diensten niet ontstaan door bevelen of
#   -   -   -   - gevorderde diensten toegekend een voortdu¬
#   -   -   -   - rend gagement van ƒ220.-'s jaars.
#   -   -   -   - Het bewijs van goed gedrag afgegeven.
#   -   -   -   - & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia
#   -   -   -   - 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I
#   -   -   -   - 6 December 1908 Ontscheept te Amsterdam en op dato ging in de
#   -   -   -   - sterkte van het korps
#   -   -   -   - 9 December 1908 Op nieuw verbinder voor een jaar, ingaan
#   -   -   -   - den 2 December 1908 om te dienen bij de Kol Res, zoowel
#   -   -   -   - in als buiten Europa met ƒ 50 - fr.s. waarvan 	ƒ‎ 12.50 uitbetaald
#   -   -   -   - en 	ƒ‎ 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over
#   -   -   -   - eenkomstig de regelen door der M v K. voortgesteld.
#   -   -   -   - 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de
#   -   -   -   - Kol: Troepe zoowel in als buiten Europa in te gaan
#   -   -   -   - met den dag waarop hij phijsiek geschikt be¬
#   -   -   -   - vonden wordt voor de actieven dienst.
#   -   - structure: campaign_data
#   -   - region_text: 5 Juni 1908 Met paspoort wegens diensteindiging Zie verder N:o 7329 bij dit korps
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - 5 Juni 1908 Met paspoort we¬
#   -   -   -   - gens diensteindiging
#   -   -   -   - Zie verder N:o 7329 bij dit korps
#   -   - structure: campaign_data
#   -   -   -   - Bijgewoonde veldtochten, bekomen
#   -   -   -   - wonden, uitstekende daden;
#   -   -   -   - wanneer en op welke wijze afgegaan.
#   -   -   -   - 6
#   -   - structure: comments
#   -   - region_text: 6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47
#   -   - row_surname: Montagne
#   -   - row_name: Johannes, Jacobus
#   -   -   -   - 6 Dec. 1901. aangecomen bij
#   -   -   -   - het vaste personeel der Kol.
#   -   -   -   - Res. Gagement gestaakt
#   -   -   -   - v/m 1 Jan. 1902. Heeft
#   -   -   -   - ƒ13.88 schuld.
#   -   -   -   - Exh. 12/21 - 01 N:o 14
#   -   -   -   - Verzoek om vergoeding voor
#   -   -   -   - woninghuur afgewezen
#   -   -   -   - Exh. 7/12-07 n:o 47
#   -   - structure: comments
#   -   - region_text: J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig verblijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962)
#   -   - row_surname: 't Hart
#   -   - row_name: 56064
#   -   -   -   - J. J. Hart, Rotterdam, Goevernestraat N:o 34.
#   -   -   -   - Keert wegens 6 jarig ver¬
#   -   -   -   - blijf uit Indie terug
#   -   -   -   - Ag. n:o 8117/08.
#   -   -   -   - Ongeschikt bevonden voor een
#   -   -   -   - reengagement, geschikt voor
#   -   -   -   - de recouv. Comps
#   -   -   -   - Exh. 25 April 10 N:o 37.
#   -   -   -   - voorsoekt tijd: p
#   -   -   -   - gagement
#   -   -   -   - Exh 27. MA: 10/11 — No: 39.
#   -   -   -   - Toekenen gagement
#   -   -   -   - 5. mei 1911 - N:o 62
#   -   -   -   - een kaartje naar Amsterdam
#   -   -   -   - 5 Dec 1911
#   -   -   -   - een maal eten ad fo. 40 -
#   -   -   -   - 1912
#   -   -   -   - Den 14 December opgenomen ten Bronbeek
#   -   -   -   - Den 16 „ op verzoek ontslagen
#   -   -   -   - Exh 4 Jaar. 13. 123
#   -   -   -   - verzoekt eene betrekking
#   -   -   -   - (ag. 8. Afd 1918 - 3962)
#   -   - structure: comments
#   -   - region_text: 1707.
#   -   - row_surname: Toole
#   -   - row_name: 56220
#   -   -   -   - 1707.
#   -   - structure: comments
#   -   -   -   - OPMERKINGEN.
#   -   -   -   - 7
#   -   - structure: page_number
#   -   - region_text: 7 1707.
#   -   -   -   - 7
#   -   -   -   - 1707.

# %%
def extract_entities(items: list):
    output = []
    cur_entity_type = None
    cur_entity_content = None
    
    # print(f'extract_entities: {items}')
    
    for item in items:
        if isinstance(item, dict):
            if 'key' in item and item['key'] == 'structure':
                if cur_entity_type:
                    output.append({
                        'type': cur_entity_type,
                        'content': cur_entity_content
                    })
                cur_entity_type = item['value']
                cur_entity_content = []
            else:
                if cur_entity_type:
                    cur_entity_content.append(item)
                else:
                    output.append(item)
        elif cur_entity_type:
            cur_entity_content.append(item)
        else:
            output.append(item)
    
    if cur_entity_type:
        output.append({
            'entity_type': cur_entity_type,
            'content': cur_entity_content
        })
    
    return output
    

def preprocess_v2(element):
    if isinstance(element, dict):
        output = []

        if 'structure' in element:
            output.append({
                'key': 'structure',
                'value': element['structure']
            })
        if 'text' in element:
            output.append({
                'key': 'text',
                'value': element['text']
            })
        if 'region_text' in element:
            output.append({
                'key': 'region_text',
                'value': element['region_text']
            })
        if 'row_surname' in element:
            output.append({
                'key': 'row_surname',
                'value': element['row_surname']
            })
        if 'row_name' in element:
            output.append({
                'key': 'row_name',
                'value': element['row_name']
            })

        children = []
        for key, value in element.items():
            if child := preprocess_v2(value):
                children.append(child)
        if children:
            if all([isinstance(c, str) for c in children]):
                children = ' '.join(children)
                output.append({
                    'key': 'child_text',
                    'value': children
                })
            else:
                children = extract_entities(children)
                output.append({
                    'key': 'children',
                    'value': children
                })
            
        if len(output) == 1 and output[0]['key'] == 'text':
            output = output[0]['value']
        else:
            output = extract_entities(output)
    elif isinstance(element, list):
        output = []
        for item in element:
            if child := preprocess_v2(item):
                output.append(child)
                
        output = extract_entities(output)
    else:
        output = None
    return output

# %%
helloz = preprocess_v2(data)
helloz[0]
# Out:
# {'key': 'children',
#  'value': [[{'key': 'children',
#     'value': [[{'entity_type': 'index',
#        'content': [{'key': 'region_text', 'value': '5118 '},
#         {'key': 'row_surname', 'value': '5118'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text', 'value': '5118'}]]}]}],
#      [{'entity_type': 'page_number',
#        'content': [{'key': 'region_text', 'value': '1707 '},
#         {'key': 'children',
#          'value': [[{'key': 'child_text', 'value': '1707'}]]}]}],
#      [{'entity_type': 'index',
#        'content': [{'key': 'region_text',
#          'value': 'J.J. Montagne 5120 Montagne Johannes, Jacobus V. P. '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'J.J. Montagne 5120 Montagne Johannes, Jacobus V. P.'}]]}]}],
#      [{'entity_type': 'index',
#        'content': [{'key': 'region_text',
#          'value': '63635 5119 56220 Toole Geert '},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': '63635 5119 56220 Toole Geert'}]]}]}],
#      [{'entity_type': 'index',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Door¬ loopende nummers. 1'}]]}]}],
#      [{'entity_type': 'index',
#        'content': [{'key': 'region_text',
#          'value': "V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan "},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': "V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan"}]]}]}],
#      [{'entity_type': 'index_military',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Algemeen stamboek nummer in Indië 2'}]]}]}],
#      [{'entity_type': 'name',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'NAMEN EN VOORNAMEN. 3'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Namen der ouders, geboorteplaats, datum van geboorte, laatste woonplaats en signalement. 4'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter. '},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter.'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter '},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „ '},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „ '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „'}]]}]}],
#      [{'entity_type': 'family_data',
#        'content': [{'key': 'region_text',
#          'value': 'Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen litteeken aan den hals '},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen littee¬ ken aan den hals'}]]}]}],
#      [{'entity_type': 'muster_data',
#        'content': [{'key': 'region_text',
#          'value': '2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaarbank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uitdrukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een affaire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze militair zes jaren onafgebroken in Ned. Indië zal hebben doorgebracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden '},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': '2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaar¬ bank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over¬ 25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uit¬ drukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een af¬ faire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze mi¬ litair zes jaren onafgebroken in Ned. Indië zal hebben doorge¬ bracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden'}]]}]}],
#      [{'entity_type': 'muster_data',
#        'content': [{'key': 'region_text',
#          'value': '6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': '6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar'}]]}]}],
#      [{'entity_type': 'muster_data',
#        'content': [{'key': 'region_text',
#          'value': 'Model n°. 178 (binnenvel) Art. 319, § 1. April 1899 '},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Model n°. 178 (binnenvel) Art. 319, § 1. April 1899'}]]}]}],
#      [{'entity_type': 'muster_data',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Waar — hetzij binnen- of buitenslands — en wanneer in dienst getreden ; omschrijving van het aangegaan akkoord, en de verdere militaire loopbaan. 5'}]]}]}],
#      [{'entity_type': 'muster_data',
#        'content': [{'key': 'region_text',
#          'value': "xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amsterdam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps "},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': "xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amster¬ dam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps"}]]}]}],
#      [{'entity_type': 'campaign_data',
#        'content': [{'key': 'region_text',
#          'value': "V 2/2'50 N:o 6 dupl. pens. akte verstrekt. "},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': "V 2/2'50 N:o 6 dupl. pens. akte verstrekt."}]]}]}],
#      [{'entity_type': 'campaign_data',
#        'content': [{'key': 'region_text',
#          'value': "27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle militaire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdurend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt bevonden wordt voor de actieven dienst. "},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': "27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle mili¬ taire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdu¬ rend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt be¬ vonden wordt voor de actieven dienst."}]]}]}],
#      [{'entity_type': 'campaign_data',
#        'content': [{'key': 'region_text',
#          'value': '5 Juni 1908 Met paspoort wegens diensteindiging Zie verder N:o 7329 bij dit korps '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': '5 Juni 1908 Met paspoort we¬ gens diensteindiging Zie verder N:o 7329 bij dit korps'}]]}]}],
#      [{'entity_type': 'campaign_data',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'Bijgewoonde veldtochten, bekomen wonden, uitstekende daden; wanneer en op welke wijze afgegaan. 6'}]]}]}],
#      [{'entity_type': 'comments',
#        'content': [{'key': 'region_text',
#          'value': '6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47 '},
#         {'key': 'row_surname', 'value': 'Montagne'},
#         {'key': 'row_name', 'value': 'Johannes, Jacobus'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': '6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47'}]]}]}],
#      [{'entity_type': 'comments',
#        'content': [{'key': 'region_text',
#          'value': 'J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig verblijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962) '},
#         {'key': 'row_surname', 'value': "'t Hart"},
#         {'key': 'row_name', 'value': '56064'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text',
#             'value': 'J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig ver¬ blijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962)'}]]}]}],
#      [{'entity_type': 'comments',
#        'content': [{'key': 'region_text', 'value': '1707. '},
#         {'key': 'row_surname', 'value': 'Toole'},
#         {'key': 'row_name', 'value': '56220'},
#         {'key': 'children',
#          'value': [[{'key': 'child_text', 'value': '1707.'}]]}]}],
#      [{'entity_type': 'comments',
#        'content': [{'key': 'children',
#          'value': [[{'key': 'child_text', 'value': 'OPMERKINGEN. 7'}]]}]}],
#      [{'entity_type': 'page_number',
#        'content': [{'key': 'region_text', 'value': '7 1707. '},
#         {'key': 'children',
#          'value': [[{'key': 'child_text', 'value': '7 1707.'}]]}]}]]}]]}

# %%
len(helloz)
# Out:
# 1

# %%
def flatten_me_like_a_bus(data):
    if isinstance(data, dict):
        if 'entity_type' in data:
            data['content'] = flatten_me_like_a_bus(data['content'])
        elif 'key' in data and data['key'] == 'children':
            data['value'] = flatten_me_like_a_bus(data['value'])
            
            if isinstance(data['value'], dict) and data['value'].get('key', None) == 'children':
                data['value'] = data['value']['value']
                
            data = data['value']
        elif 'key' in data and data['key'] == 'child_text':
            data = data['value']
        elif 'key' in data and data['key'] == 'region_text':
            data = data['value']
        else:
            # data['value'] = flatten_me_like_a_bus(data['value'])
            data = f'{data["key"]}: {flatten_me_like_a_bus(data["value"])}'
    elif isinstance(data, list):
        data = [flatten_me_like_a_bus(item) for item in data]
        if len(data) == 1 and isinstance(data[0], list | str):
            data = data[0]
    elif isinstance(data, str):
        pass
    return data

flattened_data = flatten_me_like_a_bus(deepcopy(helloz))
flattened_data
# Out:
# [[{'entity_type': 'index', 'content': ['5118 ', 'row_surname: 5118', '5118']}],
#  [{'entity_type': 'page_number', 'content': ['1707 ', '1707']}],
#  [{'entity_type': 'index',
#    'content': ['J.J. Montagne 5120 Montagne Johannes, Jacobus V. P. ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'J.J. Montagne 5120 Montagne Johannes, Jacobus V. P.']}],
#  [{'entity_type': 'index',
#    'content': ['63635 5119 56220 Toole Geert ',
#     'row_surname: Toole',
#     'row_name: 56220',
#     '63635 5119 56220 Toole Geert']}],
#  [{'entity_type': 'index', 'content': 'Door¬ loopende nummers. 1'}],
#  [{'entity_type': 'index',
#    'content': ["V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan ",
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     "V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan"]}],
#  [{'entity_type': 'index_military',
#    'content': 'Algemeen stamboek nummer in Indië 2'}],
#  [{'entity_type': 'name', 'content': 'NAMEN EN VOORNAMEN. 3'}],
#  [{'entity_type': 'family_data',
#    'content': 'Namen der ouders, geboorteplaats, datum van geboorte, laatste woonplaats en signalement. 4'}],
#  [{'entity_type': 'family_data',
#    'content': ['Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter. ',
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     'Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter.']}],
#  [{'entity_type': 'family_data',
#    'content': ['Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter ',
#     'row_surname: Toole',
#     'row_name: 56220',
#     'Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter']}],
#  [{'entity_type': 'family_data',
#    'content': ['Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd']}],
#  [{'entity_type': 'family_data',
#    'content': ['Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „ ',
#     'row_surname: Toole',
#     'row_name: 56220',
#     'Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „']}],
#  [{'entity_type': 'family_data',
#    'content': ['Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „ ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „']}],
#  [{'entity_type': 'family_data',
#    'content': ['Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen litteeken aan den hals ',
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     'Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen littee¬ ken aan den hals']}],
#  [{'entity_type': 'muster_data',
#    'content': ['2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaarbank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uitdrukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een affaire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze militair zes jaren onafgebroken in Ned. Indië zal hebben doorgebracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden ',
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     '2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaar¬ bank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over¬ 25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uit¬ drukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een af¬ faire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze mi¬ litair zes jaren onafgebroken in Ned. Indië zal hebben doorge¬ bracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden']}],
#  [{'entity_type': 'muster_data',
#    'content': ['6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar']}],
#  [{'entity_type': 'muster_data',
#    'content': ['Model n°. 178 (binnenvel) Art. 319, § 1. April 1899 ',
#     'Model n°. 178 (binnenvel) Art. 319, § 1. April 1899']}],
#  [{'entity_type': 'muster_data',
#    'content': 'Waar — hetzij binnen- of buitenslands — en wanneer in dienst getreden ; omschrijving van het aangegaan akkoord, en de verdere militaire loopbaan. 5'}],
#  [{'entity_type': 'muster_data',
#    'content': ["xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amsterdam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps ",
#     'row_surname: Toole',
#     'row_name: 56220',
#     "xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amster¬ dam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps"]}],
#  [{'entity_type': 'campaign_data',
#    'content': ["V 2/2'50 N:o 6 dupl. pens. akte verstrekt. ",
#     'row_surname: Toole',
#     'row_name: 56220',
#     "V 2/2'50 N:o 6 dupl. pens. akte verstrekt."]}],
#  [{'entity_type': 'campaign_data',
#    'content': ["27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle militaire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdurend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt bevonden wordt voor de actieven dienst. ",
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     "27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle mili¬ taire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdu¬ rend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt be¬ vonden wordt voor de actieven dienst."]}],
#  [{'entity_type': 'campaign_data',
#    'content': ['5 Juni 1908 Met paspoort wegens diensteindiging Zie verder N:o 7329 bij dit korps ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '5 Juni 1908 Met paspoort we¬ gens diensteindiging Zie verder N:o 7329 bij dit korps']}],
#  [{'entity_type': 'campaign_data',
#    'content': 'Bijgewoonde veldtochten, bekomen wonden, uitstekende daden; wanneer en op welke wijze afgegaan. 6'}],
#  [{'entity_type': 'comments',
#    'content': ['6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47 ',
#     'row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47']}],
#  [{'entity_type': 'comments',
#    'content': ['J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig verblijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962) ',
#     "row_surname: 't Hart",
#     'row_name: 56064',
#     'J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig ver¬ blijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962)']}],
#  [{'entity_type': 'comments',
#    'content': ['1707. ', 'row_surname: Toole', 'row_name: 56220', '1707.']}],
#  [{'entity_type': 'comments', 'content': 'OPMERKINGEN. 7'}],
#  [{'entity_type': 'page_number', 'content': ['7 1707. ', '7 1707.']}]]

# %%
def clean_me_like_a_firehose(data):
    if isinstance(data, list):
        data = [clean_me_like_a_firehose(item) for item in data]
        data_new = []
        already_seen = set()
        for item in data:
            if isinstance(item, dict | list):
                data_new.append(item)
                continue
            
            if item in already_seen:
                continue
            already_seen.add(item)
            data_new.append(item)
        
        data = data_new
    elif isinstance(data, dict):
        if 'entity_type' in data:
            entity_type = data['entity_type']
            value = None
            if entity_type in {'comments', 'campaign_data', 'muster_data', 'index', 'family_data'}:
                value = data['content'][1:]
            else:
                value = data['content']
            
            data = {
                'entity': entity_type,
                'value': value
            }
    elif isinstance(data, str):
        data = data.strip()
    else:
        pass
    return data

cleaned_data = clean_me_like_a_firehose(deepcopy(flattened_data))
cleaned_data
# Out:
# [[{'entity': 'index', 'value': ['row_surname: 5118', '5118']}],
#  [{'entity': 'page_number', 'value': ['1707 ', '1707']}],
#  [{'entity': 'index',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'J.J. Montagne 5120 Montagne Johannes, Jacobus V. P.']}],
#  [{'entity': 'index',
#    'value': ['row_surname: Toole',
#     'row_name: 56220',
#     '63635 5119 56220 Toole Geert']}],
#  [{'entity': 'index', 'value': 'oor¬ loopende nummers. 1'}],
#  [{'entity': 'index',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     "V.6-2-40 N:o 24 Afwijzing steunverzoek. 5118 56064 't Hart Jan"]}],
#  [{'entity': 'index_military',
#    'value': 'Algemeen stamboek nummer in Indië 2'}],
#  [{'entity': 'name', 'value': 'NAMEN EN VOORNAMEN. 3'}],
#  [{'entity': 'family_data',
#    'value': 'amen der ouders, geboorteplaats, datum van geboorte, laatste woonplaats en signalement. 4'}],
#  [{'entity': 'family_data',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     'Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter.']}],
#  [{'entity': 'family_data',
#    'value': ['row_surname: Toole',
#     'row_name: 56220',
#     'Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter']}],
#  [{'entity': 'family_data',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd']}],
#  [{'entity': 'family_data',
#    'value': ['row_surname: Toole',
#     'row_name: 56220',
#     'Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „']}],
#  [{'entity': 'family_data',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     'Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „']}],
#  [{'entity': 'family_data',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     'Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen littee¬ ken aan den hals']}],
#  [{'entity': 'muster_data',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     '2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaar¬ bank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over¬ 25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uit¬ drukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een af¬ faire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze mi¬ litair zes jaren onafgebroken in Ned. Indië zal hebben doorge¬ bracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden']}],
#  [{'entity': 'muster_data',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar']}],
#  [{'entity': 'muster_data',
#    'value': ['Model n°. 178 (binnenvel) Art. 319, § 1. April 1899']}],
#  [{'entity': 'muster_data',
#    'value': 'aar — hetzij binnen- of buitenslands — en wanneer in dienst getreden ; omschrijving van het aangegaan akkoord, en de verdere militaire loopbaan. 5'}],
#  [{'entity': 'muster_data',
#    'value': ['row_surname: Toole',
#     'row_name: 56220',
#     "xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amster¬ dam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps"]}],
#  [{'entity': 'campaign_data',
#    'value': ['row_surname: Toole',
#     'row_name: 56220',
#     "V 2/2'50 N:o 6 dupl. pens. akte verstrekt."]}],
#  [{'entity': 'campaign_data',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     "27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle mili¬ taire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdu¬ rend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt be¬ vonden wordt voor de actieven dienst."]}],
#  [{'entity': 'campaign_data',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '5 Juni 1908 Met paspoort we¬ gens diensteindiging Zie verder N:o 7329 bij dit korps']}],
#  [{'entity': 'campaign_data',
#    'value': 'ijgewoonde veldtochten, bekomen wonden, uitstekende daden; wanneer en op welke wijze afgegaan. 6'}],
#  [{'entity': 'comments',
#    'value': ['row_surname: Montagne',
#     'row_name: Johannes, Jacobus',
#     '6 Dec. 1901. aangecomen bij het vaste personeel der Kol. Res. Gagement gestaakt v/m 1 Jan. 1902. Heeft ƒ13.88 schuld. Exh. 12/21 - 01 N:o 14 Verzoek om vergoeding voor woninghuur afgewezen Exh. 7/12-07 n:o 47']}],
#  [{'entity': 'comments',
#    'value': ["row_surname: 't Hart",
#     'row_name: 56064',
#     'J. J. Hart, Rotterdam, Goevernestraat N:o 34. Keert wegens 6 jarig ver¬ blijf uit Indie terug Ag. n:o 8117/08. Ongeschikt bevonden voor een reengagement, geschikt voor de recouv. Comps Exh. 25 April 10 N:o 37. voorsoekt tijd: p gagement Exh 27. MA: 10/11 — No: 39. Toekenen gagement 5. mei 1911 - N:o 62 een kaartje naar Amsterdam 5 Dec 1911 een maal eten ad fo. 40 - 1912 Den 14 December opgenomen ten Bronbeek Den 16 „ op verzoek ontslagen Exh 4 Jaar. 13. 123 verzoekt eene betrekking (ag. 8. Afd 1918 - 3962)']}],
#  [{'entity': 'comments',
#    'value': ['row_surname: Toole', 'row_name: 56220', '1707.']}],
#  [{'entity': 'comments', 'value': 'PMERKINGEN. 7'}],
#  [{'entity': 'page_number', 'value': ['7 1707. ', '7 1707.']}]]

# %%
def pannekoek(data):
    output = []
    
    def inner_pannekoek(data):
        if isinstance(data, dict):
            output.append(data)
        elif isinstance(data, list):
            for item in data:
                inner_pannekoek(item)
        else:
            pass
    
    inner_pannekoek(data)
    
    title = None
    people = []
    events = []
    
    for entity in output:
        if entity['entity'] in ['campaign_data', 'muster_data']:
            value = entity['value'] if isinstance(entity['value'], str) else entity['value']
            events.append(value)
        elif entity['entity'] in [ 'family_data']:
            value = entity['value'] if isinstance(entity['value'], str) else entity['value']
            people.append(value)
        elif entity['entity'] in ['index_military']:
            title = entity['value']
        else:
            pass
        

    
    return {
        'title': title,
        'people': people,
        'events': events
    }


result = pannekoek(deepcopy(cleaned_data))
result
# Out:
# {'title': 'Algemeen stamboek nummer in Indië 2',
#  'people': ['amen der ouders, geboorteplaats, datum van geboorte, laatste woonplaats en signalement. 4',
#   ["row_surname: 't Hart",
#    'row_name: 56064',
#    'Vader Jan Moeder Catharina van Bemmel Geboren te Leiderdorp /Z.H. den 12:e November 1883 Laatst gewoond te Rotterdam Bij zijne aankomst bij het korps lang 1:667 Meter.'],
#   ['row_surname: Toole',
#    'row_name: 56220',
#    'Vader Hendrik Moeder Jantje Baptist Geboren te Borger (Drenthe) den 15 Augustus 1875 Laatst gewoond te Borger Bij zijne aankomst bij het korp lang 1.708 Meter'],
#   ['row_surname: Montagne',
#    'row_name: Johannes, Jacobus',
#    'Vader Johannes Moeder Jannetje van der Meer Geboren te Leiden (Zuid-Holl:d.) 30:en Januari 1862 den Laatst gewoond te Leiden Bij zijne aankomst bij het korps lang 1.563 Meter. Gehuwd'],
#   ['row_surname: Toole',
#    'row_name: 56220',
#    'Haar Kin Aangezicht Ovaal Voorhoofd smal Oogen bruin Neus gewoon Mond id rond blond Wenkbrauwen id Merkbare teekenen  „'],
#   ['row_surname: Montagne',
#    'row_name: Johannes, Jacobus',
#    'Aangezicht ovaal Voorhoofd hoog Oogen blauw Neus gewoon Mond klein Kin rond Haar bruin Wenkbrauwen id Merkbare teekenen „'],
#   ["row_surname: 't Hart",
#    'row_name: 56064',
#    'Aangezicht rond Voorhoofd gewoon Oogen grijs Neus gewoon Mond klein Kin rond Haar blond Wenkbrauwen id Merkbare teekenen littee¬ ken aan den hals']],
#  'events': [["row_surname: 't Hart",
#    'row_name: 56064',
#    '2 December 1901 Vrijwillig geengageerd als soldaat voor zes jaren bij het leger zoowel in als buiten Europa met ƒ300 - premie waarvan f 50 - uitbetaald en ƒ 250 - in \'s Rijkspostspaar¬ bank ingelegd is Gedetacheerd naar Oost-Indië en op dato te Amsterdam over¬ 25 October 1902 gegaan aan boord van het SS„ Prins Hendrik" 1 December 1902 Gedebarkeerd te Batavia en geplaatst bij het 2:e Depot. Bat:on 5 Mei 1903 Overgegaan bij het 5 Bat:on Inf:ie 4 Juli 1905 „  „ „ strafdetachement (bewak: det:t) „  „ „ 5 Bat:en Int:ie 26 October 1905 Voor der krijgsraad te Magelang en op dato in preventie 16 April 1906 hechtenis. Bij vonnis van dien krijgsraad dd. 27 April 1906, bekrachtigd bij arrest van het H. M. Gdd 18 Mei 1906 ingaande vf. dien datum veroordeeld tot een jaar militaire gevangenisstraf wegens het als minder militaire uit¬ drukkelijk weigeren en opzettelijk nalaten, de orders van dengenen die boven hem gesteld is, te gehoorzamen en na te komen in eene andere gelegenheid der in een af¬ faire tegen den vijand of in eene plaats welke dadelijk belegerd of bekend is 1 Juni 1906 ter executie gelegd. 18 Mei 1907 Van militaire gevangens ontslagen en geplaatst bij het 2:e Depot Bat:en Overgegaan bij het 5 Bat:en Inf:ie 5 October 1907 28 December 1907 „  „  „ 9:\' „  „ 10 Juli 1908 Bestemd om op of "zoo" kort mogelijk voor den dag, dat deze mi¬ litair zes jaren onafgebroken in Ned. Indië zal hebben doorge¬ bracht, gerekend van en met den dag van inscheping herwaerts naar Nederland te worden opgezonden'],
#   ['row_surname: Montagne',
#    'row_name: Johannes, Jacobus',
#    '6 December 1901 6 „ 1902 6 Juni 1903 6 - „ 1904 6 - „ 1905 31 Augustus 1905 6 Juni 1906 4 „ 1907 Zie Suppletie folio 33143 33143 Vrijwillig geengageerd als soldaat voor een jaar bij het vaste personeel van de Reconvalescenten afdeeling Gereëngageerd voor zes maanden. Gereëngageerd voor een jaar Gereëngeerd voor een jaar Gereëngageerd voor een jaar Korporaal Opnieuw verbonden voor een jaar Idem  „ een jaar'],
#   ['Model n°. 178 (binnenvel) Art. 319, § 1. April 1899'],
#   'aar — hetzij binnen- of buitenslands — en wanneer in dienst getreden ; omschrijving van het aangegaan akkoord, en de verdere militaire loopbaan. 5',
#   ['row_surname: Toole',
#    'row_name: 56220',
#    "xx Toole N:o 5119. 18 april 1908 Gedetacheerd naar Oost-Indië en op dato te Amster¬ dam overgegaan dan boord van het SS„ Oranje” 23 Mei 1908 Gedebarkeerd te Batavia en geplaatst by het 1:e Depot Bat: 26 Augustus 1908 Overgegaan bij het 18:' Bat:on Inf:ie 5Juni 1909 Bestemd om naar Nederland te worden opgezonden daar zijn gezondheidstoestand dit noodig maakt 10 „ 1909 ter opzending naar Nederland overgegaan bij het Subskader te Batavia 17 „ 1909 derwaarts vertrokken met het SS„ Koning Willem I” 21 Juli 1909 Ontscheept te Amsterdam en op dato terug in de sterkte van het korps"],
#   ['row_surname: Toole',
#    'row_name: 56220',
#    "V 2/2'50 N:o 6 dupl. pens. akte verstrekt."],
#   ["row_surname: 't Hart",
#    'row_name: 56064',
#    "27 Mei 1911 Uit de sterkte gebracht, zijnde aan hem bij Kon. besluit dd 3 Mei 1911 n:o 51, wegens voortdurende ongeschiktheid voor alle mili¬ taire diensten niet ontstaan door bevelen of gevorderde diensten toegekend een voortdu¬ rend gagement van ƒ220.-'s jaars. Het bewijs van goed gedrag afgegeven. & 28 Octob 1908 ter opzend hij naar Nederland overgegaan b/h SK K Batavia 5 November 1908 derwaarts vertrokken b/h SS Kon. Willem I 6 December 1908 Ontscheept te Amsterdam en op dato ging in de sterkte van het korps 9 December 1908 Op nieuw verbinder voor een jaar, ingaan den 2 December 1908 om te dienen bij de Kol Res, zoowel in als buiten Europa met ƒ 50 - fr.s. waarvan \tƒ\u200e 12.50 uitbetaald en \tƒ\u200e 37.50 te zynen behoeve in's Rpostsp, ingeschreven is, over eenkomstig de regelen door der M v K. voortgesteld. 14 Mei 1910 Op nieuw verbonden voor drie jaren, bij de Kol: Troepe zoowel in als buiten Europa in te gaan met den dag waarop hij phijsiek geschikt be¬ vonden wordt voor de actieven dienst."],
#   ['row_surname: Montagne',
#    'row_name: Johannes, Jacobus',
#    '5 Juni 1908 Met paspoort we¬ gens diensteindiging Zie verder N:o 7329 bij dit korps'],
#   'ijgewoonde veldtochten, bekomen wonden, uitstekende daden; wanneer en op welke wijze afgegaan. 6']}

# %%
with open('out.json', 'w') as f:
    json.dump(result, f, indent=2)
